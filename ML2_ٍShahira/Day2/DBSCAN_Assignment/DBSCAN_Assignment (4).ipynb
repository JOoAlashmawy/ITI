# %%
#!pip install pandas plotnine
# use any plotting library seaborn matplotlib,..........
from sklearn.neighbors import NearestNeighbors
from sklearn import datasets

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm
import seaborn as sns
import pandas as pd

from sklearn.cluster import KMeans
import scipy.cluster.hierarchy as shc
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import DBSCAN


from sklearn.preprocessing import StandardScaler
#from plotnine import *

# %%
n_samples = 1500
dataset1 = sklearn.datasets.make_circles(n_samples=n_samples, factor=.5, noise=.05)
dataset1=pd.DataFrame(dataset1[0])
dataset2 = sklearn.datasets.make_moons(n_samples=n_samples, noise=.05)
dataset2=pd.DataFrame(dataset2[0])

dataset3 = sklearn.datasets.make_blobs(n_samples=n_samples, random_state=8)
dataset3=pd.DataFrame(dataset3[0])

dataset4= np.random.rand(n_samples, 2), None
dataset4=pd.DataFrame(dataset4[0])
path = 'D:/AI/1-Technical_ITI/02-Phase_2/04-ML2/Day2/'
dataset5= pd.read_csv(path + "data/dataset5.csv")
dataset6= pd.read_csv(path + "data/dataset6.csv")
dataset7= pd.read_csv(path + "data/dataset7.csv")
dataset8= pd.read_csv(path + "data/dataset8.csv")
dataset9= pd.read_csv(path + "data/dataset9.csv")
datasets=[dataset1]
z = StandardScaler()
dataset1[["x","y"]] = z.fit_transform(dataset1)
dataset2[["x","y"]] = z.fit_transform(dataset2)
dataset3[["x","y"]] = z.fit_transform(dataset3)
dataset4[["x","y"]] = z.fit_transform(dataset4)
dataset5[["x","y"]] = z.fit_transform(dataset5)
dataset6[["x","y"]] = z.fit_transform(dataset6)
dataset7[["x","y"]] = z.fit_transform(dataset7)
dataset8[["x","y"]] = z.fit_transform(dataset8)
dataset9[["x","y"]] = z.fit_transform(dataset9)
#sns.scatterplot(x = dataset6['x'],y = dataset6['y']) 
dataset1.head()
# Out:
#           0         1         x         y
# 0  0.498462  0.099013  0.883621  0.177209
# 1 -0.968922 -0.403298 -1.725943 -0.717965
# 2 -0.535305  0.640558 -0.954809  1.142299
# 3 -0.303596  0.368125 -0.542742  0.656795
# 4  0.735317  0.629319  1.304839  1.122270

# %%
K_M_d1 = KMeans(n_clusters = 2)
K_M_d1.fit(dataset1)

all_iner = []
for i in range(1,15):
    K_M = KMeans(n_clusters = i,random_state = 0)
    K_M.fit(dataset1)
    all_iner.append(K_M.inertia_)

    
plt.plot(all_iner)
plt.title('Elbow method')
plt.xlabel('N Cluster')
plt.ylabel('inertia')
# Out:
# Text(0, 0.5, 'inertia')

# %%
sns.scatterplot(x = dataset1['x'],y = dataset1['y'], hue = K_M_d1.labels_)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
plt.figure(figsize=(20, 20))
plt.title("Counters Dendograms")
dend = shc.dendrogram(shc.linkage(y=dataset1 , method='ward', metric='euclidean'),orientation='right') #fill y with your dataframe

# %%
aggler_d1 = AgglomerativeClustering(n_clusters=2, linkage='ward')
aggler_d1.fit(dataset1)
sns.scatterplot(x = dataset1['x'],y = dataset1['y'], hue = aggler_d1.labels_)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
DBS_d1 = DBSCAN(eps=0.4, min_samples=10)
DBS_d1.fit(dataset1)
sns.scatterplot(x = dataset1['x'],y = dataset1['y'], hue = DBS_d1.labels_)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
clustering_labels = DBS_d1.fit_predict(dataset1) 
silhouette_score(dataset1, clustering_labels)
# Out:
# 0.11565015857094056

# %%
K_M_d2 = KMeans(n_clusters = 2)
K_M_d2.fit(dataset2)

all_iner = []
for i in range(1,15):
    K_M = KMeans(n_clusters = i,random_state = 0)
    K_M.fit(dataset2)
    all_iner.append(K_M.inertia_)

    
plt.plot(all_iner)
plt.title('Elbow method')
plt.xlabel('N Cluster')
plt.ylabel('inertia')
# Out:
# Text(0, 0.5, 'inertia')

# %%
sns.scatterplot(x = dataset2['x'],y = dataset2['y'], hue = K_M_d2.labels_)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
plt.figure(figsize=(20, 20))
plt.title("Counters Dendograms")
dend = shc.dendrogram(shc.linkage(y=dataset2 , method='ward', metric='euclidean'),orientation='right') #fill y with your dataframe

# %%
aggler_d2 = AgglomerativeClustering(n_clusters=2, linkage='ward')
aggler_d2.fit(dataset2)
sns.scatterplot(x = dataset2['x'],y = dataset2['y'], hue = aggler_d2.labels_)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
DBS_d2 = DBSCAN(eps=0.5, min_samples=10)
DBS_d2.fit(dataset2)
sns.scatterplot(x = dataset2['x'],y = dataset2['y'], hue = DBS_d2.labels_)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
clustering_labels = DBS_d2.fit_predict(dataset2) 
silhouette_score(dataset2, clustering_labels)
# Out:
# 0.37697560619662546

# %%
K_M_d3 = KMeans(n_clusters = 3)
K_M_d3.fit(dataset3)

all_iner = []
for i in range(1,15):
    K_M = KMeans(n_clusters = i,random_state = 0)
    K_M.fit(dataset3)
    all_iner.append(K_M.inertia_)

    
plt.plot(all_iner)
plt.title('Elbow method')
plt.xlabel('N Cluster')
plt.ylabel('inertia')
# Out:
# Text(0, 0.5, 'inertia')

# %%
sns.scatterplot(x = dataset3['x'],y = dataset3['y'], hue = K_M_d3.labels_)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
plt.figure(figsize=(20, 20))
plt.title("Counters Dendograms")
dend = shc.dendrogram(shc.linkage(y=dataset3 , method='ward', metric='euclidean'),orientation='right') #fill y with your dataframe

# %%
aggler_d3 = AgglomerativeClustering(n_clusters=3, linkage='ward')
aggler_d3.fit(dataset3)
sns.scatterplot(x = dataset3['x'],y = dataset3['y'], hue = aggler_d3.labels_)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
DBS_d3 = DBSCAN(eps=0.5, min_samples=5)
DBS_d3.fit(dataset3)
sns.scatterplot(x = dataset3['x'],y = dataset3['y'], hue = DBS_d3.labels_)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
clustering_labels = DBS_d3.fit_predict(dataset3) 
silhouette_score(dataset3, clustering_labels)
# Out:
# 0.7945552747272735

# %%
K_M_d4 = KMeans(n_clusters = 3)
K_M_d4.fit(dataset4)

all_iner = []
for i in range(1,15):
    K_M = KMeans(n_clusters = i,random_state = 0)
    K_M.fit(dataset4)
    all_iner.append(K_M.inertia_)

    
plt.plot(all_iner)
plt.title('Elbow method')
plt.xlabel('N Cluster')
plt.ylabel('inertia')
# Out:
# Text(0, 0.5, 'inertia')

# %%
sns.scatterplot(x = dataset4['x'],y = dataset4['y'], hue = K_M_d4.labels_)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
plt.figure(figsize=(20, 20))
plt.title("Counters Dendograms")
dend = shc.dendrogram(shc.linkage(y=dataset4 , method='ward', metric='euclidean'),orientation='right') #fill y with your dataframe

# %%
aggler_d4 = AgglomerativeClustering(n_clusters=4, linkage='ward')
aggler_d4.fit(dataset4)
sns.scatterplot(x = dataset4['x'],y = dataset4['y'], hue = aggler_d4.labels_)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
DBS_d4 = DBSCAN(eps=0.1, min_samples=2)
DBS_d4.fit(dataset4)
sns.scatterplot(x = dataset4['x'],y = dataset4['y'], hue = DBS_d4.labels_)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
clustering_labels = DBS_d4.fit_predict(dataset4) 
silhouette_score(dataset4, clustering_labels)
# Out:
# 0.032541720208384695

# %%
K_M_d5 = KMeans(n_clusters = 2)
K_M_d5.fit(dataset5)

all_iner = []
for i in range(1,15):
    K_M = KMeans(n_clusters = i,random_state = 0)
    K_M.fit(dataset5)
    all_iner.append(K_M.inertia_)

    
plt.plot(all_iner)
plt.title('Elbow method')
plt.xlabel('N Cluster')
plt.ylabel('inertia')
# Out:
# Text(0, 0.5, 'inertia')

# %%
sns.scatterplot(x = dataset5['x'],y = dataset5['y'], hue = K_M_d5.labels_)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
plt.figure(figsize=(20, 20))
plt.title("Counters Dendograms")
dend = shc.dendrogram(shc.linkage(y=dataset5 , method='ward', metric='euclidean'),orientation='right') #fill y with your dataframe

# %%
aggler_d5 = AgglomerativeClustering(n_clusters=2, linkage='ward')
aggler_d5.fit(dataset5)
sns.scatterplot(x = dataset5['x'],y = dataset5['y'], hue = aggler_d5.labels_)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
DBS_d5 = DBSCAN(eps=0.4, min_samples=10)
DBS_d5.fit(dataset5)
sns.scatterplot(x = dataset5['x'],y = dataset5['y'], hue = DBS_d5.labels_)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
clustering_labels = DBS_d5.fit_predict(dataset5) 
silhouette_score(dataset5, clustering_labels)
# Out:
# 0.21242436639127313

# %%
K_M_d6 = KMeans(n_clusters = 2)
K_M_d6.fit(dataset6)

all_iner = []
for i in range(1,15):
    K_M = KMeans(n_clusters = i,random_state = 0)
    K_M.fit(dataset6)
    all_iner.append(K_M.inertia_)

    
plt.plot(all_iner)
plt.title('Elbow method')
plt.xlabel('N Cluster')
plt.ylabel('inertia')
# Out:
# Text(0, 0.5, 'inertia')

# %%
sns.scatterplot(x = dataset6['x'],y = dataset6['y'], hue = K_M_d6.labels_)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
plt.figure(figsize=(20, 20))
plt.title("Counters Dendograms")
dend = shc.dendrogram(shc.linkage(y=dataset6 , method='ward', metric='euclidean'),orientation='right') #fill y with your dataframe

# %%
aggler_d6 = AgglomerativeClustering(n_clusters=3, linkage='ward')
aggler_d6.fit(dataset6)
sns.scatterplot(x = dataset6['x'],y = dataset6['y'], hue = aggler_d6.labels_)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
DBS_d6 = DBSCAN(eps=0.5, min_samples=10)
DBS_d6.fit(dataset6)
sns.scatterplot(x = dataset6['x'],y = dataset6['y'], hue = DBS_d6.labels_)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
clustering_labels = DBS_d6.fit_predict(dataset6) 
silhouette_score(dataset6, clustering_labels)
# Out:
# 0.2384941595219719

# %%
K_M_d7 = KMeans(n_clusters = 3)
K_M_d7.fit(dataset7)

all_iner = []
for i in range(1,15):
    K_M = KMeans(n_clusters = i,random_state = 0)
    K_M.fit(dataset7)
    all_iner.append(K_M.inertia_)

    
plt.plot(all_iner)
plt.title('Elbow method')
plt.xlabel('N Cluster')
plt.ylabel('inertia')
# Out:
# Text(0, 0.5, 'inertia')

# %%
sns.scatterplot(x = dataset7['x'],y = dataset7['y'], hue = K_M_d7.labels_)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
plt.figure(figsize=(20, 20))
plt.title("Counters Dendograms")
dend = shc.dendrogram(shc.linkage(y=dataset7 , method='ward', metric='euclidean'),orientation='right') #fill y with your dataframe

# %%
aggler_d7 = AgglomerativeClustering(n_clusters=3, linkage='ward')
aggler_d7.fit(dataset7)
sns.scatterplot(x = dataset7['x'],y = dataset7['y'], hue = aggler_d7.labels_)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
DBS_d7 = DBSCAN(eps=0.5, min_samples=10)
DBS_d7.fit(dataset7)
sns.scatterplot(x = dataset7['x'],y = dataset7['y'], hue = DBS_d7.labels_)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
clustering_labels = DBS_d7.fit_predict(dataset7) 
silhouette_score(dataset7, clustering_labels)
# Out:
# 0.9135255096218113

# %%
K_M_d8 = KMeans(n_clusters = 3)
K_M_d8.fit(dataset8)

all_iner = []
for i in range(1,15):
    K_M = KMeans(n_clusters = i,random_state = 0)
    K_M.fit(dataset8)
    all_iner.append(K_M.inertia_)

    
plt.plot(all_iner)
plt.title('Elbow method')
plt.xlabel('N Cluster')
plt.ylabel('inertia')
# Out:
# Text(0, 0.5, 'inertia')

# %%
sns.scatterplot(x = dataset8['x'],y = dataset8['y'], hue = K_M_d8.labels_)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
plt.figure(figsize=(20, 20))
plt.title("Counters Dendograms")
dend = shc.dendrogram(shc.linkage(y=dataset8 , method='ward', metric='euclidean'),orientation='right') #fill y with your dataframe

# %%
aggler_d8 = AgglomerativeClustering(n_clusters=3, linkage='ward')
aggler_d8.fit(dataset8)
sns.scatterplot(x = dataset8['x'],y = dataset8['y'], hue = aggler_d8.labels_)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
DBS_d8 = DBSCAN(eps=0.5, min_samples=10)
DBS_d8.fit(dataset8)
sns.scatterplot(x = dataset8['x'],y = dataset8['y'], hue = DBS_d8.labels_)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
clustering_labels = DBS_d8.fit_predict(dataset8) 
silhouette_score(dataset8, clustering_labels)
# Out:
# 0.6700704240910447

# %%
K_M_d9 = KMeans(n_clusters = 3)
K_M_d9.fit(dataset9)

all_iner = []
for i in range(1,15):
    K_M = KMeans(n_clusters = i,random_state = 0)
    K_M.fit(dataset9)
    all_iner.append(K_M.inertia_)

    
plt.plot(all_iner)
plt.title('Elbow method')
plt.xlabel('N Cluster')
plt.ylabel('inertia')
# Out:
# Text(0, 0.5, 'inertia')

# %%
sns.scatterplot(x = dataset9['x'],y = dataset9['y'], hue = K_M_d9.labels_)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
plt.figure(figsize=(20, 20))
plt.title("Counters Dendograms")
dend = shc.dendrogram(shc.linkage(y=dataset9 , method='ward', metric='euclidean'),orientation='right') #fill y with your dataframe

# %%
aggler_d9 = AgglomerativeClustering(n_clusters=3, linkage='ward')
aggler_d9.fit(dataset9)
sns.scatterplot(x = dataset9['x'],y = dataset9['y'], hue = aggler_d9.labels_)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
DBS_d9 = DBSCAN(eps=0.4, min_samples=7)
DBS_d9.fit(dataset9)
sns.scatterplot(x = dataset9['x'],y = dataset9['y'], hue = DBS_d9.labels_)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
clustering_labels = DBS_d9.fit_predict(dataset9) 
silhouette_score(dataset9, clustering_labels)
# Out:
# 0.5361158145429892

# %% [markdown]
# 1) plot all dataset
# 2) use standard scalar
# 3) use K-means, agglomerative, dbscan
# 4) plot dataset after clustering
# 5) Evaluate inertia,silhouette score,..........

# %%
mins = 3
nn = NearestNeighbors(n_neighbors=4)

nn.fit(dataset9[["x", "y"]])

distances, neighbors = nn.kneighbors(dataset9[["x", "y"]])

distances = np.sort(distances[:, mins], axis = 0)
X=list(range(0,len(distances)))
plt.plot(X,distances)
