# %% [markdown]
# # PySpark H.W Session 1

# %% [markdown]
# Let's get some quick practice with your new Spark DataFrame skills, you will be asked some basic questions about some stock market data, in this case Walmart Stock from the years 2012-2017. This exercise will just ask a bunch of questions, unlike the future machine learning exercises, which will be a little looser and be in the form of "Consulting Projects", but more on that later!
#
# For now, just answer the questions and complete the tasks below.

# %% [markdown]
# #### Use the walmart_stock.csv file to Answer and complete the  tasks below!

# %% [markdown]
# #### Start a simple Spark Session

# %%
import findspark
findspark.init()
import pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("walmart_stock").getOrCreate()
# Out:
# 21/10/21 18:19:13 WARN Utils: Your hostname, ubuntu resolves to a loopback address: 127.0.1.1; using 192.168.137.130 instead (on interface ens33)
# 21/10/21 18:19:13 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/opt/spark/jars/spark-unsafe_2.12-3.1.1.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# 21/10/21 18:19:14 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# ...

# %% [markdown]
# #### Load the Walmart Stock CSV File, have Spark infer the data types.

# %%
df = spark.read.csv("walmart_stock.csv", header=True, inferSchema=True)

# %% [markdown]
# #### What are the column names?

# %%
df.columns
# Out:
# ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Adj Close']

# %% [markdown]
# #### What does the Schema look like?

# %%
df.printSchema()
# Out:
# root
#  |-- Date: string (nullable = true)
#  |-- Open: double (nullable = true)
#  |-- High: double (nullable = true)
#  |-- Low: double (nullable = true)
#  |-- Close: double (nullable = true)
#  |-- Volume: integer (nullable = true)
#  |-- Adj Close: double (nullable = true)

# %% [markdown]
# #### Print out the first 5 columns.

# %%
for i in df.head(5):
    
  print(i)
# Out:
# Row(Date='2012-01-03', Open=59.970001, High=61.060001, Low=59.869999, Close=60.330002, Volume=12668800, Adj Close=52.619234999999996)
# Row(Date='2012-01-04', Open=60.209998999999996, High=60.349998, Low=59.470001, Close=59.709998999999996, Volume=9593300, Adj Close=52.078475)
# Row(Date='2012-01-05', Open=59.349998, High=59.619999, Low=58.369999, Close=59.419998, Volume=12768200, Adj Close=51.825539)
# Row(Date='2012-01-06', Open=59.419998, High=59.450001, Low=58.869999, Close=59.0, Volume=8069400, Adj Close=51.45922)
# Row(Date='2012-01-09', Open=59.029999, High=59.549999, Low=58.919998, Close=59.18, Volume=6679300, Adj Close=51.616215000000004)

# %% [markdown]
# #### Use describe() to learn about the DataFrame.

# %%
df.describe()
# Out:
# DataFrame[summary: string, Date: string, Open: string, High: string, Low: string, Close: string, Volume: string, Adj Close: string]

# %%
df.show()
# Out:
# +----------+------------------+------------------+------------------+------------------+--------+------------------+
# |      Date|              Open|              High|               Low|             Close|  Volume|         Adj Close|
# +----------+------------------+------------------+------------------+------------------+--------+------------------+
# |2012-01-03|         59.970001|         61.060001|         59.869999|         60.330002|12668800|52.619234999999996|
# |2012-01-04|60.209998999999996|         60.349998|         59.470001|59.709998999999996| 9593300|         52.078475|
# |2012-01-05|         59.349998|         59.619999|         58.369999|         59.419998|12768200|         51.825539|
# |2012-01-06|         59.419998|         59.450001|         58.869999|              59.0| 8069400|          51.45922|
# |2012-01-09|         59.029999|         59.549999|         58.919998|             59.18| 6679300|51.616215000000004|
# ...

# %% [markdown]
# ## Bonus Question!
# #### There are too many decimal places for mean and stddev in the describe() dataframe. Format the numbers to just show up to two decimal places. Pay careful attention to the datatypes that .describe() returns, we didn't cover how to do this exact formatting, but we covered something very similar. [Check this link for a hint](http://spark.apache.org/docs/latest/api/python/pyspark.sql.html#pyspark.sql.Column.cast)
#
# If you get stuck on this, don't worry, just view the solutions.

# %%
# Out:
# root
#  |-- summary: string (nullable = true)
#  |-- Open: string (nullable = true)
#  |-- High: string (nullable = true)
#  |-- Low: string (nullable = true)
#  |-- Close: string (nullable = true)
#  |-- Volume: string (nullable = true)
#  |-- Adj Close: string (nullable = true)

# %%
# Out:
# +-------+--------+--------+--------+--------+--------+
# |summary|    Open|    High|     Low|   Close|  Volume|
# +-------+--------+--------+--------+--------+--------+
# |  count|1,258.00|1,258.00|1,258.00|1,258.00|    1258|
# |   mean|   72.36|   72.84|   71.92|   72.39| 8222093|
# | stddev|    6.77|    6.77|    6.74|    6.76| 4519781|
# |    min|   56.39|   57.06|   56.30|   56.42| 2094900|
# |    max|   90.80|   90.97|   89.25|   90.47|80898100|
# +-------+--------+--------+--------+--------+--------+

# %% [markdown]
# #### Create a new dataframe with a column called HV Ratio that is the ratio of the High Price versus volume of stock traded for a day.

# %%
from pyspark.sql.functions import *
df2 = df.select(expr('High/Volume').alias('HV Radio'))
df2.show(20)
# Out:
# +--------------------+
# |            HV Radio|
# +--------------------+
# |4.819714653321546E-6|
# |6.290848613094555E-6|
# |4.669412994783916E-6|
# |7.367338463826307E-6|
# |8.915604778943901E-6|
# |8.644477436914568E-6|
# |9.351828421515645E-6|
# | 8.29141562102703E-6|
# |7.712212102001476E-6|
# |7.071764823529412E-6|
# |1.015495466386981E-5|
# |6.576354146362592...|
# | 5.90145296180676E-6|
# |8.547679455011844E-6|
# |8.420709512685392E-6|
# |1.041448341728929...|
# |8.316075414862431E-6|
# |9.721183814992126E-6|
# |8.029436027707578E-6|
# |6.307432259386365E-6|
# +--------------------+
# only showing top 20 rows

# %% [markdown]
# #### What day had the Peak High in Price?

# %%
df.groupby('Date').agg({'High':'max'}).sort(col('max(High)').desc()).collect()[0][0]
# Out:
# '2015-01-13'

# %% [markdown]
# #### What is the mean of the Close column?

# %%
df.agg({'Close':'avg'}).show()
# Out:
# +-----------------+
# |       avg(Close)|
# +-----------------+
# |72.38844998012726|
# +-----------------+

# %% [markdown]
# #### What is the max and min of the Volume column?

# %%
exprs = [max(col('Volume')) , min(col('Volume')) ]
df.agg(*exprs).show()
# Out:
# +-----------+-----------+
# |max(Volume)|min(Volume)|
# +-----------+-----------+
# |   80898100|    2094900|
# +-----------+-----------+

# %%
# Out:
# +-----------+-----------+
# |max(Volume)|min(Volume)|
# +-----------+-----------+
# |   80898100|    2094900|
# +-----------+-----------+

# %% [markdown]
# #### How many days was the Close lower than 60 dollars?

# %%
df.select(col('Date')).where(col('Close')<60).count()
# Out:
# 81

# %%
# Out:
# 81

# %% [markdown]
# #### What percentage of the time was the High greater than 80 dollars ?
# #### In other words, (Number of Days High>80)/(Total Days in the dataset)

# %%
df.select(col('Date')).where(col('High')>80).count()/df.select(col('Date')).count()*100
# Out:
# 9.141494435612083

# %%
# Out:
# 9.141494435612083

# %% [markdown]
# #### What is the Pearson correlation between High and Volume?
# #### [Hint](http://spark.apache.org/docs/latest/api/python/pyspark.sql.html#pyspark.sql.DataFrameStatFunctions.corr)

# %%
df.corr('High','Volume')
# Out:
# -0.3384326061737161

# %%
# Out:
# +-------------------+
# | corr(High, Volume)|
# +-------------------+
# |-0.3384326061737161|
# +-------------------+

# %% [markdown]
# #### What is the max High per year?

# %%
df.select(to_timestamp(df.t, 'yyyy-MM-dd ').alias('dt')).collect()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_15466/3469027280.py in <module>
# ----> 1 df.select(to_timestamp(df.t, 'yyyy-MM-dd ').alias('dt')).collect()
#
# /opt/spark/python/pyspark/sql/dataframe.py in __getattr__(self, name)
#    1641         """
#    1642         if name not in self.columns:
# -> 1643             raise AttributeError(
#    1644                 "'%s' object has no attribute '%s'" % (self.__class__.__name__, name))
#    1645         jc = self._jdf.apply(name)
#
# AttributeError: 'DataFrame' object has no attribute 't'

# %%
# Out:
# +----+---------+
# |Year|max(High)|
# +----+---------+
# |2015|90.970001|
# |2013|81.370003|
# |2014|88.089996|
# |2012|77.599998|
# |2016|75.190002|
# +----+---------+

# %% [markdown]
# #### What is the average Close for each Calendar Month?
# #### In other words, across all the years, what is the average Close price for Jan,Feb, Mar, etc... Your result will have a value for each of these months.

# %%
# Out:
# +-----+-----------------+
# |Month|       avg(Close)|
# +-----+-----------------+
# |    1|71.44801958415842|
# |    2|  71.306804443299|
# |    3|71.77794377570092|
# |    4|72.97361900952382|
# |    5|72.30971688679247|
# |    6| 72.4953774245283|
# |    7|74.43971943925233|
# |    8|73.02981855454546|
# |    9|72.18411785294116|
# |   10|71.57854545454543|
# |   11| 72.1110893069307|
# |   12|72.84792478301885|
# +-----+-----------------+
