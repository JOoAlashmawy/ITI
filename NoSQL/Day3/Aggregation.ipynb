# %%
from pymongo import MongoClient

# %% [markdown]
# # Connecting to MongoDB

# %%
client = MongoClient("mongodb://localhost:27017")

# %% [markdown]
# # Helper Functions

# %%
def print_cursor(c):
    for i in cursor:
        print(i)

# %% [markdown]
# # Dataset 1

# %%
db = client.universities

# %%
client.drop_database("universities")

# %%
db.universities.insert_many([
{
  "country" : "Spain",
  "city" : "Salamanca",
  "name" : "USAL",
  "location" : {
    "type" : "Point",
    "coordinates" : [ -5.6722512,17, 40.9607792 ]
  },
  "students" : [
    { "year" : 2014, "number" : 24774 },
    { "year" : 2015, "number" : 23166 },
    { "year" : 2016, "number" : 21913 },
    { "year" : 2017, "number" : 21715 }
  ]
},
{
  "country" : "Spain",
  "city" : "Salamanca",
  "name" : "UPSA",
  "location" : {
    "type" : "Point",
    "coordinates" : [ -5.6691191,17, 40.9631732 ]
  },
  "students" : [
    { "year" : 2014, "number" : 4788 },
    { "year" : 2015, "number" : 4821 },
    { "year" : 2016, "number" : 6550 },
    { "year" : 2017, "number" : 6125 }
  ]
}
])


db.courses.insert_many([
{
  "university" : "USAL",
  "name" : "Computer Science",
  "level" : "Excellent"
},
{
  "university" : "USAL",
  "name" : "Electronics",
  "level" : "Intermediate"
},
{
  "university" : "USAL",
  "name" : "Communication",
  "level" : "Excellent"
}
])

# %% [markdown]
# # Aggregation stages

# %% [markdown]
# ## MongoDB `$match`

# %%
cursor = db.universities.aggregate([
  { "$match" : { "country" : "Spain", "city" : "Salamanca" } }
])

print_cursor(cursor)
# Out:
# {'_id': ObjectId('611d18308ba0e401218f6be1'), 'country': 'Spain', 'city': 'Salamanca', 'name': 'USAL', 'location': {'type': 'Point', 'coordinates': [-5.6722512, 17, 40.9607792]}, 'students': [{'year': 2014, 'number': 24774}, {'year': 2015, 'number': 23166}, {'year': 2016, 'number': 21913}, {'year': 2017, 'number': 21715}]}
# {'_id': ObjectId('611d18308ba0e401218f6be2'), 'country': 'Spain', 'city': 'Salamanca', 'name': 'UPSA', 'location': {'type': 'Point', 'coordinates': [-5.6691191, 17, 40.9631732]}, 'students': [{'year': 2014, 'number': 4788}, {'year': 2015, 'number': 4821}, {'year': 2016, 'number': 6550}, {'year': 2017, 'number': 6125}]}

# %% [markdown]
# ## MongoDB `$project`

# %%
cursor = db.universities.aggregate([
  { "$project" : { "_id" : 0, "country" : 1, "city" : 1 } }
])

print_cursor(cursor)
# Out:
# {'country': 'Spain', 'city': 'Salamanca'}
# {'country': 'Spain', 'city': 'Salamanca'}

# %% [markdown]
# ## MongoDB `$group`

# %%
cursor = db.universities.aggregate([
  { "$group" : { "_id" : "$city", "totaldocs" : { "$sum" : 1 } } }
])

print_cursor(cursor)
# Out:
# {'_id': 'Salamanca', 'totaldocs': 2}

# %% [markdown]
# ## MongoDB `$out`

# %%
db.universities.aggregate([
  { "$group" : { "_id" : "$city", "totaldocs" : { "$sum" : 1 } } },
      { "$out" : "aggResults" } #record in Results 
])

cursor = db.aggResults.find()
print_cursor(cursor)
# Out:
# {'_id': 'Salamanca', 'totaldocs': 2}

# %% [markdown]
# ## MongoDB `$unwind`

# %%
cursor = db.universities.aggregate([
  { "$match" : { "name" : "USAL" } },
  { "$unwind" : "$students" } #extract the array and use the supelements to create new documents with it 
])

print_cursor(cursor)
# Out:
# {'_id': ObjectId('611d18308ba0e401218f6be1'), 'country': 'Spain', 'city': 'Salamanca', 'name': 'USAL', 'location': {'type': 'Point', 'coordinates': [-5.6722512, 17, 40.9607792]}, 'students': {'year': 2014, 'number': 24774}}
# {'_id': ObjectId('611d18308ba0e401218f6be1'), 'country': 'Spain', 'city': 'Salamanca', 'name': 'USAL', 'location': {'type': 'Point', 'coordinates': [-5.6722512, 17, 40.9607792]}, 'students': {'year': 2015, 'number': 23166}}
# {'_id': ObjectId('611d18308ba0e401218f6be1'), 'country': 'Spain', 'city': 'Salamanca', 'name': 'USAL', 'location': {'type': 'Point', 'coordinates': [-5.6722512, 17, 40.9607792]}, 'students': {'year': 2016, 'number': 21913}}
# {'_id': ObjectId('611d18308ba0e401218f6be1'), 'country': 'Spain', 'city': 'Salamanca', 'name': 'USAL', 'location': {'type': 'Point', 'coordinates': [-5.6722512, 17, 40.9607792]}, 'students': {'year': 2017, 'number': 21715}}

# %% [markdown]
# ## MongoDB `$sort`

# %%
cursor = db.universities.aggregate([
  { "$match" : { "city" : "Salamanca" } },
  { "$unwind" : "$students" },
  { "$project" : { "_id" : 0, "name": 1, "students.year" : 1, "students.number" : 1 } },
  { "$sort" : { "students.number" : -1 } }#descending
])

print_cursor(cursor)
# Out:
# {'name': 'USAL', 'students': {'year': 2014, 'number': 24774}}
# {'name': 'USAL', 'students': {'year': 2015, 'number': 23166}}
# {'name': 'USAL', 'students': {'year': 2016, 'number': 21913}}
# {'name': 'USAL', 'students': {'year': 2017, 'number': 21715}}
# {'name': 'UPSA', 'students': {'year': 2016, 'number': 6550}}
# {'name': 'UPSA', 'students': {'year': 2017, 'number': 6125}}
# {'name': 'UPSA', 'students': {'year': 2015, 'number': 4821}}
# {'name': 'UPSA', 'students': {'year': 2014, 'number': 4788}}

# %% [markdown]
# ## MongoDB `$limit`

# %%
cursor = db.universities.aggregate([
  { "$match" : { "name" : "USAL" } },
  { "$unwind" : "$students" },
  { "$project" : { "_id" : 0, "students.year" : 1, "students.number" : 1 } },
  { "$sort" : { "students.number" : -1 } },
  { "$limit" : 3 }
])

print_cursor(cursor)
# Out:
# {'students': {'year': 2014, 'number': 24774}}
# {'students': {'year': 2015, 'number': 23166}}
# {'students': {'year': 2016, 'number': 21913}}

# %% [markdown]
# ## MongoDB `$addFields`

# %%
# cursor = db.universities.aggregate([
#   { "$match" : { "name" : "USAL" } },
#   { "$addFields" : { "foundation_year" : 1218 } }
# ])
cursor = db.universities.aggregate([
  { "$match" : { "name" : "UPSA" } },
  { "$addFields" : { "foundation_year" : 1220 } }
])

print_cursor(cursor)
# Out:
# {'_id': ObjectId('611d18308ba0e401218f6be2'), 'country': 'Spain', 'city': 'Salamanca', 'name': 'UPSA', 'location': {'type': 'Point', 'coordinates': [-5.6691191, 17, 40.9631732]}, 'students': [{'year': 2014, 'number': 4788}, {'year': 2015, 'number': 4821}, {'year': 2016, 'number': 6550}, {'year': 2017, 'number': 6125}], 'foundation_year': 1220}

# %% [markdown]
# ## MongoDB `$count`

# %%
cursor = db.universities.aggregate([
  { "$match" : { "name" : "USAL" } },
  { "$unwind" : "$students" },
  { "$count" : "total_documents" }
])

print_cursor(cursor)
# Out:
# {'total_documents': 4}

# %% [markdown]
# ## MongoDB `$lookup`

# %% [markdown]
# If you want this query to run fast, you are going to need to index the `name` field in the `universities` collection and the `university` field in the `courses` collection.

# %%
cursor = db.universities.aggregate([
  { "$match" : { "name" : "USAL" } },
  { "$project" : { "_id" : 0, "name" : 1 } },
  { "$lookup" : {
      "from" : "courses",
      "localField" : "name",
      "foreignField" : "university",
      "as" : "courses"
  } },
  { "$project" : { "_id" : 0, "courses.university": 1, "courses.name" : 1  } }
])

print_cursor(cursor)
# Out:
# {'courses': [{'university': 'USAL', 'name': 'Computer Science'}, {'university': 'USAL', 'name': 'Electronics'}, {'university': 'USAL', 'name': 'Communication'}]}

# %% [markdown]
# ## MongoDB `$sortByCount`

# %% [markdown]
# This stage is a shortcut for grouping, counting and then sorting in descending order the number of different values in a field.

# %%
# cursor = db.courses.aggregate([
#   { "$sortByCount" : "$level" }
# ])
cursor = db.universities.aggregate([
  { "$sortByCount" : "$country" }
])

print_cursor(cursor)
# Out:
# {'_id': 'Spain', 'count': 2}

# %% [markdown]
# ## MongoDB `$facet`

# %% [markdown]
# Sometimes when creating a report on data, you find that you need to do the same preliminary processing for a number of reports, and you are faced with having to create and maintain an intermediate collection.

# %%
cursor = db.universities.aggregate([
  { "$match" : { "name" : "USAL" } },
  { "$lookup" : {
      "from" : "courses",
      "localField" : "name",
      "foreignField" : "university",
      "as" : "courses"
  } }
])

print_cursor(cursor)
# Out:
# {'_id': ObjectId('611d18308ba0e401218f6be1'), 'country': 'Spain', 'city': 'Salamanca', 'name': 'USAL', 'location': {'type': 'Point', 'coordinates': [-5.6722512, 17, 40.9607792]}, 'students': [{'year': 2014, 'number': 24774}, {'year': 2015, 'number': 23166}, {'year': 2016, 'number': 21913}, {'year': 2017, 'number': 21715}], 'courses': [{'_id': ObjectId('611d18308ba0e401218f6be3'), 'university': 'USAL', 'name': 'Computer Science', 'level': 'Excellent'}, {'_id': ObjectId('611d18308ba0e401218f6be4'), 'university': 'USAL', 'name': 'Electronics', 'level': 'Intermediate'}, {'_id': ObjectId('611d18308ba0e401218f6be5'), 'university': 'USAL', 'name': 'Communication', 'level': 'Excellent'}]}

# %%
cursor = db.universities.aggregate([
  { "$match" : { "name" : "USAL" } },
  { "$lookup" : {
      "from" : "courses",
      "localField" : "name",
      "foreignField" : "university",
      "as" : "courses"
  } },
         { "$unwind" : "$courses" },
#          { "$sortByCount" : "$courses.level" }
        { "$sortByCount" : "$courses.name" }
])

print_cursor(cursor)
# Out:
# {'_id': 'Communication', 'count': 1}
# {'_id': 'Electronics', 'count': 1}
# {'_id': 'Computer Science', 'count': 1}

# %%
cursor = db.universities.aggregate([
  { "$match" : { "name" : "USAL" } },
  { "$lookup" : {
      "from" : "courses",
      "localField" : "name",
      "foreignField" : "university",
      "as" : "courses"
  } },
         { "$unwind" : "$students" },
         { "$project" : { "_id" : 0, "students" : 1 } },
         { "$sort" : { "students.number" : 1 } }, # ascending
         { "$limit" : 1 }
])

print_cursor(cursor)
# Out:
# {'students': {'year': 2017, 'number': 21715}}

# %%
cursor = db.universities.aggregate([
  { "$match" : { "name" : "USAL" } },
  { "$lookup" : {
      "from" : "courses",
      "localField" : "name",
      "foreignField" : "university",
      "as" : "courses"
  } },
  { "$facet" : {
      "countingLevels" :
      [
         { "$unwind" : "$courses" },
         { "$sortByCount" : "$courses.level" }
#          { "$sortByCount" : "$courses.name" }
      ],
      "yearWithLessStudents" :
      [
         { "$unwind" : "$students" },
         { "$project" : { "_id" : 0, "students" : 1 } },
         { "$sort" : { "students.number" : 1 } },
         { "$limit" : 1 }
      ]
  } }
])

print_cursor(cursor)
# Out:
# {'countingLevels': [{'_id': 'Excellent', 'count': 2}, {'_id': 'Intermediate', 'count': 1}], 'yearWithLessStudents': [{'students': {'year': 2017, 'number': 21715}}]}

# %% [markdown]
# # Dataset 2

# %% [markdown]
# Use `mongoimport` to load http://media.mongodb.org/zips.json into your mongod instance.

# %%
db = client.zips

# %%
cursor = db.zipcodes.find({"_id" : "47906"})
print_cursor(cursor)
# Out:
# {'_id': '47906', 'city': 'WEST LAFAYETTE', 'loc': [-86.923661, 40.444025], 'pop': 54702, 'state': 'IN'}

# %% [markdown]
# # Aggregation Pipeline

# %% [markdown]
# ### Return States with Populations above 10 Million

# %% [markdown]
# `SELECT state, SUM(pop) AS totalPop
# FROM zipcodes
# GROUP BY state
# HAVING totalPop >= (10*1000*1000)`

# %%
cursor = db.zipcodes.aggregate( [
   { "$group": { "_id": "$state", "totalPop": { "$sum": "$pop" } } },
#    { "$match": { "totalPop": { "$gte": 10*1000*1000 } } } #greater
   { "$match": { "totalPop": { "$lte": 10*1000*1000 } } } #less
] )

print_cursor(cursor)
# Out:
# {'_id': 'SD', 'totalPop': 695397}
# {'_id': 'AR', 'totalPop': 2350725}
# {'_id': 'WA', 'totalPop': 4866692}
# {'_id': 'MS', 'totalPop': 2573216}
# {'_id': 'AK', 'totalPop': 544698}
# {'_id': 'OK', 'totalPop': 3145585}
# {'_id': 'VT', 'totalPop': 562758}
# {'_id': 'GA', 'totalPop': 6478216}
# {'_id': 'AL', 'totalPop': 4040587}
# {'_id': 'WI', 'totalPop': 4891769}
# {'_id': 'HI', 'totalPop': 1108229}
# {'_id': 'MT', 'totalPop': 798948}
# {'_id': 'UT', 'totalPop': 1722850}
# {'_id': 'TN', 'totalPop': 4876457}
# {'_id': 'SC', 'totalPop': 3486703}
# {'_id': 'DC', 'totalPop': 606900}
# {'_id': 'MI', 'totalPop': 9295297}
# {'_id': 'DE', 'totalPop': 666168}
# {'_id': 'ID', 'totalPop': 1006749}
# {'_id': 'IA', 'totalPop': 2776420}
# {'_id': 'KY', 'totalPop': 3675484}
# {'_id': 'RI', 'totalPop': 1003218}
# {'_id': 'MD', 'totalPop': 4781379}
# {'_id': 'LA', 'totalPop': 4217595}
# {'_id': 'CO', 'totalPop': 3293755}
# {'_id': 'VA', 'totalPop': 6181479}
# {'_id': 'NM', 'totalPop': 1515069}
# {'_id': 'OR', 'totalPop': 2842321}
# {'_id': 'CT', 'totalPop': 3287116}
# {'_id': 'WV', 'totalPop': 1793146}
# {'_id': 'NE', 'totalPop': 1578139}
# {'_id': 'MA', 'totalPop': 6016425}
# {'_id': 'ME', 'totalPop': 1226648}
# {'_id': 'IN', 'totalPop': 5544136}
# {'_id': 'KS', 'totalPop': 2475285}
# {'_id': 'NJ', 'totalPop': 7730188}
# {'_id': 'NH', 'totalPop': 1109252}
# {'_id': 'MN', 'totalPop': 4372982}
# {'_id': 'WY', 'totalPop': 453528}
# {'_id': 'MO', 'totalPop': 5110648}
# {'_id': 'ND', 'totalPop': 638272}
# {'_id': 'NV', 'totalPop': 1201833}
# {'_id': 'NC', 'totalPop': 6628637}
# {'_id': 'AZ', 'totalPop': 3665228}

# %% [markdown]
# ### Return Average City Population by State

# %%
cursor = db.zipcodes.aggregate( [
   { "$group": { "_id": { "state": "$state", "city": "$city" }, "pop": { "$sum": "$pop" } } },
   { "$sort": { "_id.state": 1 } }
] )

print_cursor(cursor)
# Out:
# {'_id': {'state': 'AK', 'city': 'PORT HEIDEN'}, 'pop': 119}
# {'_id': {'state': 'AK', 'city': 'RUSSIAN MISSION'}, 'pop': 0}
# {'_id': {'state': 'AK', 'city': 'POINT HOPE'}, 'pop': 640}
# {'_id': {'state': 'AK', 'city': 'ELMENDORF AFB'}, 'pop': 7907}
# {'_id': {'state': 'AK', 'city': 'COLDFOOT'}, 'pop': 19316}
# {'_id': {'state': 'AK', 'city': 'CRAIG'}, 'pop': 1398}
# {'_id': {'state': 'AK', 'city': 'CLAM GULCH'}, 'pop': 133}
# {'_id': {'state': 'AK', 'city': 'KWETHLUK'}, 'pop': 558}
# {'_id': {'state': 'AK', 'city': 'PEDRO BAY'}, 'pop': 59}
# {'_id': {'state': 'AK', 'city': 'KALTAG'}, 'pop': 240}
# {'_id': {'state': 'AK', 'city': 'KAKTOVIK'}, 'pop': 245}
# {'_id': {'state': 'AK', 'city': 'SHUNGNAK'}, 'pop': 0}
# {'_id': {'state': 'AK', 'city': 'MC GRATH'}, 'pop': 618}
# {'_id': {'state': 'AK', 'city': 'POINT LAY'}, 'pop': 139}
# {'_id': {'state': 'AK', 'city': 'SAVOONGA'}, 'pop': 519}
# {'_id': {'state': 'AK', 'city': 'AMBLER'}, 'pop': 8}
# {'_id': {'state': 'AK', 'city': 'NORTH POLE'}, 'pop': 14672}
# {'_id': {'state': 'AK', 'city': 'LAKE MINCHUMINA'}, 'pop': 32}
# {'_id': {'state': 'AK', 'city': 'SAINT MARYS'}, 'pop': 576}
# {'_id': {'state': 'AK', 'city': 'STERLING'}, 'pop': 3814}
# {'_id': {'state': 'AK', 'city': 'RAMPART'}, 'pop': 68}
# {'_id': {'state': 'AK', 'city': 'RUBY'}, 'pop': 172}
# {'_id': {'state': 'AK', 'city': 'GOLOVIN'}, 'pop': 3706}
# {'_id': {'state': 'AK', 'city': 'CHENEGA BAY'}, 'pop': 96}
# {'_id': {'state': 'AK', 'city': 'LOWER KALSKAG'}, 'pop': 291}
# {'_id': {'state': 'AK', 'city': 'PRUDHOE BAY'}, 'pop': 153}
# {'_id': {'state': 'AK', 'city': 'CLARKS POINT'}, 'pop': 68}
# {'_id': {'state': 'AK', 'city': 'TULUKSAK'}, 'pop': 358}
# {'_id': {'state': 'AK', 'city': 'HAINES'}, 'pop': 2246}
# {'_id': {'state': 'AK', 'city': 'WILLOW'}, 'pop': 1237}
# {'_id': {'state': 'AK', 'city': 'EGEGIK'}, 'pop': 122}
# {'_id': {'state': 'AK', 'city': 'GRAYLING'}, 'pop': 0}
# {'_id': {'state': 'AK', 'city': 'VENETIE'}, 'pop': 184}
# {'_id': {'state': 'AK', 'city': 'BETTLES FIELD'}, 'pop': 156}
# {'_id': {'state': 'AK', 'city': 'ALAKANUK'}, 'pop': 1186}
# {'_id': {'state': 'AK', 'city': 'NIKOLAI'}, 'pop': 109}
# {'_id': {'state': 'AK', 'city': 'NAKNEK'}, 'pop': 0}
# {'_id': {'state': 'AK', 'city': 'CHEVAK'}, 'pop': 0}
# {'_id': {'state': 'AK', 'city': 'EIELSON AFB'}, 'pop': 5266}
# {'_id': {'state': 'AK', 'city': 'PETERSBURG'}, 'pop': 4253}
# {'_id': {'state': 'AK', 'city': 'CENTRAL'}, 'pop': 107}
# {'_id': {'state': 'AK', 'city': 'MOUNTAIN VILLAGE'}, 'pop': 788}
# {'_id': {'state': 'AK', 'city': 'MINTO'}, 'pop': 228}
# {'_id': {'state': 'AK', 'city': 'CHALKYITSIK'}, 'pop': 99}
# {'_id': {'state': 'AK', 'city': 'AKUTAN'}, 'pop': 589}
# {'_id': {'state': 'AK', 'city': 'HEALY'}, 'pop': 1057}
# {'_id': {'state': 'AK', 'city': 'SITKA'}, 'pop': 8638}
# {'_id': {'state': 'AK', 'city': 'SAND POINT'}, 'pop': 881}
# {'_id': {'state': 'AK', 'city': 'CROOKED CREEK'}, 'pop': 1}
# {'_id': {'state': 'AK', 'city': 'NULATO'}, 'pop': 492}
# {'_id': {'state': 'AK', 'city': 'COOPER LANDING'}, 'pop': 252}
# {'_id': {'state': 'AK', 'city': 'SKAGWAY'}, 'pop': 692}
# {'_id': {'state': 'AK', 'city': 'FAIRBANKS'}, 'pop': 31379}
# {'_id': {'state': 'AK', 'city': 'KOBUK'}, 'pop': 306}
# {'_id': {'state': 'AK', 'city': 'SAINT GEORGE ISL'}, 'pop': 138}
# {'_id': {'state': 'AK', 'city': 'NOATAK'}, 'pop': 395}
# {'_id': {'state': 'AK', 'city': 'CIRCLE'}, 'pop': 73}
# {'_id': {'state': 'AK', 'city': 'KETCHIKAN'}, 'pop': 14308}
# {'_id': {'state': 'AK', 'city': 'FALSE PASS'}, 'pop': 68}
# {'_id': {'state': 'AK', 'city': 'NUIQSUT'}, 'pop': 354}
# {'_id': {'state': 'AK', 'city': 'SHISHMAREF'}, 'pop': 456}
# {'_id': {'state': 'AK', 'city': 'POINT BAKER'}, 'pop': 426}
# {'_id': {'state': 'AK', 'city': 'IGIUGIG'}, 'pop': 480}
# {'_id': {'state': 'AK', 'city': 'KING COVE'}, 'pop': 451}
# {'_id': {'state': 'AK', 'city': 'SCAMMON BAY'}, 'pop': 343}
# {'_id': {'state': 'AK', 'city': 'SELAWIK'}, 'pop': 0}
# {'_id': {'state': 'AK', 'city': 'KWIGILLINGOK'}, 'pop': 572}
# {'_id': {'state': 'AK', 'city': 'KOLIGANEK'}, 'pop': 2711}
# {'_id': {'state': 'AK', 'city': 'GAMBELL'}, 'pop': 525}
# {'_id': {'state': 'AK', 'city': 'AKIAK'}, 'pop': 285}
# {'_id': {'state': 'AK', 'city': 'ANCHORAGE'}, 'pop': 183987}
# {'_id': {'state': 'AK', 'city': 'NINILCHIK'}, 'pop': 767}
# {'_id': {'state': 'AK', 'city': 'ELIM'}, 'pop': 264}
# {'_id': {'state': 'AK', 'city': 'EEK'}, 'pop': 254}
# {'_id': {'state': 'AK', 'city': 'JUNEAU'}, 'pop': 24947}
# {'_id': {'state': 'AK', 'city': 'BUCKLAND'}, 'pop': 318}
# {'_id': {'state': 'AK', 'city': 'COPPER CENTER'}, 'pop': 1389}
# {'_id': {'state': 'AK', 'city': 'HYDABURG'}, 'pop': 891}
# {'_id': {'state': 'AK', 'city': 'ANVIK'}, 'pop': 296}
# {'_id': {'state': 'AK', 'city': 'KASILOF'}, 'pop': 963}
# {'_id': {'state': 'AK', 'city': 'KOTZEBUE'}, 'pop': 3347}
# {'_id': {'state': 'AK', 'city': 'BEAVER'}, 'pop': 103}
# {'_id': {'state': 'AK', 'city': 'HOONAH'}, 'pop': 1670}
# {'_id': {'state': 'AK', 'city': 'TRAPPER CREEK'}, 'pop': 20}
# {'_id': {'state': 'AK', 'city': 'CHUATHBALUK'}, 'pop': 352}
# {'_id': {'state': 'AK', 'city': 'FORT RICHARDSON'}, 'pop': 7979}
# {'_id': {'state': 'AK', 'city': 'MANLEY HOT SPRIN'}, 'pop': 122}
# {'_id': {'state': 'AK', 'city': 'GLENNALLEN'}, 'pop': 1024}
# {'_id': {'state': 'AK', 'city': 'SAINT PAUL ISLAN'}, 'pop': 763}
# {'_id': {'state': 'AK', 'city': 'METLAKATLA'}, 'pop': 1469}
# {'_id': {'state': 'AK', 'city': 'DOUGLAS'}, 'pop': 1802}
# {'_id': {'state': 'AK', 'city': 'STEBBINS'}, 'pop': 400}
# {'_id': {'state': 'AK', 'city': 'SHAGELUK'}, 'pop': 139}
# {'_id': {'state': 'AK', 'city': 'UNALAKLEET'}, 'pop': 716}
# {'_id': {'state': 'AK', 'city': 'KENAI'}, 'pop': 10508}
# {'_id': {'state': 'AK', 'city': 'AKHIOK'}, 'pop': 13309}
# {'_id': {'state': 'AK', 'city': 'ALEKNAGIK'}, 'pop': 185}
# {'_id': {'state': 'AK', 'city': 'MOOSE PASS'}, 'pop': 1649}
# {'_id': {'state': 'AK', 'city': 'BREVIG MISSION'}, 'pop': 198}
# {'_id': {'state': 'AK', 'city': 'DENALI NATIONAL'}, 'pop': 27}
# {'_id': {'state': 'AK', 'city': 'NOORVIK'}, 'pop': 534}
# {'_id': {'state': 'AK', 'city': 'DUTCH HARBOR'}, 'pop': 3}
# {'_id': {'state': 'AK', 'city': 'KIANA'}, 'pop': 349}
# {'_id': {'state': 'AK', 'city': 'ARCTIC VILLAGE'}, 'pop': 107}
# {'_id': {'state': 'AK', 'city': 'EMMONAK'}, 'pop': 0}
# {'_id': {'state': 'AK', 'city': 'PLATINUM'}, 'pop': 4}
# {'_id': {'state': 'AK', 'city': 'ANGOON'}, 'pop': 1002}
# {'_id': {'state': 'AK', 'city': 'SOLDOTNA'}, 'pop': 9825}
# {'_id': {'state': 'AK', 'city': 'MEKORYUK'}, 'pop': 177}
# {'_id': {'state': 'AK', 'city': 'ANDERSON'}, 'pop': 300}
# {'_id': {'state': 'AK', 'city': 'WHITE MOUNTAIN'}, 'pop': 194}
# {'_id': {'state': 'AK', 'city': 'DEERING'}, 'pop': 167}
# {'_id': {'state': 'AK', 'city': 'VALDEZ'}, 'pop': 7049}
# {'_id': {'state': 'AK', 'city': 'ANAKTUVUK PASS'}, 'pop': 260}
# {'_id': {'state': 'AK', 'city': 'KOTLIK'}, 'pop': 462}
# {'_id': {'state': 'AK', 'city': 'KLAWOCK'}, 'pop': 851}
# {'_id': {'state': 'AK', 'city': 'KALSKAG'}, 'pop': 172}
# {'_id': {'state': 'AK', 'city': 'FORT YUKON'}, 'pop': 662}
# {'_id': {'state': 'AK', 'city': 'PORT ALSWORTH'}, 'pop': 7}
# {'_id': {'state': 'AK', 'city': 'LEVELOCK'}, 'pop': 204}
# {'_id': {'state': 'AK', 'city': 'SOUTH NAKNEK'}, 'pop': 929}
# {'_id': {'state': 'AK', 'city': 'PILOT STATION'}, 'pop': 463}
# {'_id': {'state': 'AK', 'city': 'GUSTAVUS'}, 'pop': 258}
# {'_id': {'state': 'AK', 'city': 'PILOT POINT'}, 'pop': 63}
# {'_id': {'state': 'AK', 'city': 'KIPNUK'}, 'pop': 470}
# {'_id': {'state': 'AK', 'city': 'MANOKOTAK'}, 'pop': 385}
# {'_id': {'state': 'AK', 'city': 'SHAKTOOLIK'}, 'pop': 183}
# {'_id': {'state': 'AK', 'city': 'STEVENS VILLAGE'}, 'pop': 110}
# {'_id': {'state': 'AK', 'city': 'NAPAKIAK'}, 'pop': 328}
# {'_id': {'state': 'AK', 'city': 'PERRYVILLE'}, 'pop': 143}
# {'_id': {'state': 'AK', 'city': 'ALLAKAKET'}, 'pop': 170}
# {'_id': {'state': 'AK', 'city': 'THORNE BAY'}, 'pop': 744}
# {'_id': {'state': 'AK', 'city': 'GOODNEWS BAY'}, 'pop': 305}
# {'_id': {'state': 'AK', 'city': 'SALCHA'}, 'pop': 890}
# {'_id': {'state': 'AK', 'city': 'NENANA'}, 'pop': 393}
# {'_id': {'state': 'AK', 'city': 'BUTTE'}, 'pop': 12358}
# {'_id': {'state': 'AK', 'city': 'EKWOK'}, 'pop': 77}
# {'_id': {'state': 'AK', 'city': 'TELLER'}, 'pop': 260}
# {'_id': {'state': 'AK', 'city': 'CLEAR'}, 'pop': 440}
# {'_id': {'state': 'AK', 'city': 'NIKOLSKI'}, 'pop': 42}
# {'_id': {'state': 'AK', 'city': 'UNALASKA'}, 'pop': 3089}
# {'_id': {'state': 'AK', 'city': 'WALES'}, 'pop': 341}
# {'_id': {'state': 'AK', 'city': 'HOOPER BAY'}, 'pop': 1443}
# {'_id': {'state': 'AK', 'city': 'FORT WAINWRIGHT'}, 'pop': 6238}
# {'_id': {'state': 'AK', 'city': 'TANANA'}, 'pop': 345}
# {'_id': {'state': 'AK', 'city': 'MARSHALL'}, 'pop': 530}
# {'_id': {'state': 'AK', 'city': 'HUGHES'}, 'pop': 64}
# {'_id': {'state': 'AK', 'city': 'AKIACHAK'}, 'pop': 481}
# {'_id': {'state': 'AK', 'city': 'HOLY CROSS'}, 'pop': 277}
# {'_id': {'state': 'AK', 'city': 'RED DEVIL'}, 'pop': 159}
# {'_id': {'state': 'AK', 'city': 'NEW STUYAHOK'}, 'pop': 586}
# {'_id': {'state': 'AK', 'city': 'KOYUK'}, 'pop': 231}
# {'_id': {'state': 'AK', 'city': 'ATMAUTLUAK'}, 'pop': 7188}
# {'_id': {'state': 'AK', 'city': 'YAKUTAT'}, 'pop': 705}
# {'_id': {'state': 'AK', 'city': 'CHIGNIK'}, 'pop': 188}
# {'_id': {'state': 'AK', 'city': 'TUNUNAK'}, 'pop': 889}
# {'_id': {'state': 'AK', 'city': 'SEWARD'}, 'pop': 3937}
# {'_id': {'state': 'AK', 'city': 'HYDER'}, 'pop': 116}
# {'_id': {'state': 'AK', 'city': 'BORDER'}, 'pop': 1805}
# {'_id': {'state': 'AK', 'city': 'PORT GRAHAM'}, 'pop': 8186}
# {'_id': {'state': 'AK', 'city': 'CANTWELL'}, 'pop': 210}
# {'_id': {'state': 'AK', 'city': 'DOT LAKE'}, 'pop': 4111}
# {'_id': {'state': 'AK', 'city': 'CHIGNIK LAGOON'}, 'pop': 186}
# {'_id': {'state': 'AK', 'city': 'WRANGELL'}, 'pop': 2573}
# {'_id': {'state': 'AK', 'city': 'CHEFORNAK'}, 'pop': 320}
# {'_id': {'state': 'AK', 'city': 'WASILLA'}, 'pop': 24619}
# {'_id': {'state': 'AK', 'city': 'TALKEETNA'}, 'pop': 1420}
# {'_id': {'state': 'AK', 'city': 'CHUGIAK'}, 'pop': 6910}
# {'_id': {'state': 'AK', 'city': 'KIVALINA'}, 'pop': 689}
# {'_id': {'state': 'AK', 'city': 'SLANA'}, 'pop': 394}
# {'_id': {'state': 'AK', 'city': 'SLEETMUTE'}, 'pop': 0}
# {'_id': {'state': 'AK', 'city': 'WAINWRIGHT'}, 'pop': 492}
# {'_id': {'state': 'AK', 'city': 'KOKHANOK'}, 'pop': 362}
# {'_id': {'state': 'AK', 'city': 'NONDALTON'}, 'pop': 233}
# {'_id': {'state': 'AK', 'city': 'QUINHAGAK'}, 'pop': 501}
# {'_id': {'state': 'AK', 'city': 'EAGLE RIVER'}, 'pop': 18429}
# {'_id': {'state': 'AK', 'city': 'GALENA'}, 'pop': 847}
# {'_id': {'state': 'AK', 'city': 'SAINT MICHAEL'}, 'pop': 295}
# {'_id': {'state': 'AK', 'city': 'HUSLIA'}, 'pop': 207}
# {'_id': {'state': 'AK', 'city': 'BARROW'}, 'pop': 3696}
# {'_id': {'state': 'AK', 'city': 'NIKOLAEVSK'}, 'pop': 1698}
# {'_id': {'state': 'AK', 'city': 'NELSON LAGOON'}, 'pop': 475}
# {'_id': {'state': 'AK', 'city': 'TYONEK'}, 'pop': 277}
# {'_id': {'state': 'AL', 'city': 'HODGES'}, 'pop': 798}
# {'_id': {'state': 'AL', 'city': 'DIXONS MILLS'}, 'pop': 2635}
# {'_id': {'state': 'AL', 'city': 'LUVERNE'}, 'pop': 4274}
# {'_id': {'state': 'AL', 'city': 'LENOX'}, 'pop': 515}
# {'_id': {'state': 'AL', 'city': 'VALLEY'}, 'pop': 9504}
# {'_id': {'state': 'AL', 'city': 'HARPERSVILLE'}, 'pop': 4905}
# {'_id': {'state': 'AL', 'city': 'LYNN'}, 'pop': 1778}
# {'_id': {'state': 'AL', 'city': 'MARION JUNCTION'}, 'pop': 796}
# {'_id': {'state': 'AL', 'city': 'STEVENSON'}, 'pop': 5210}
# {'_id': {'state': 'AL', 'city': 'PISGAH'}, 'pop': 3717}
# {'_id': {'state': 'AL', 'city': 'GROVE HILL'}, 'pop': 4089}
# {'_id': {'state': 'AL', 'city': 'JACKSONVILLE'}, 'pop': 16438}
# {'_id': {'state': 'AL', 'city': 'HENAGAR'}, 'pop': 2973}
# {'_id': {'state': 'AL', 'city': 'CHUNCHULA'}, 'pop': 1322}
# {'_id': {'state': 'AL', 'city': 'LEROY'}, 'pop': 1086}
# {'_id': {'state': 'AL', 'city': 'PRICHARD'}, 'pop': 24919}
# {'_id': {'state': 'AL', 'city': 'GRADY'}, 'pop': 1811}
# {'_id': {'state': 'AL', 'city': 'COLUMBIA'}, 'pop': 2934}
# {'_id': {'state': 'AL', 'city': 'BOAZ'}, 'pop': 16955}
# {'_id': {'state': 'AL', 'city': 'MONROEVILLE'}, 'pop': 10492}
# {'_id': {'state': 'AL', 'city': 'REFORM'}, 'pop': 4062}
# {'_id': {'state': 'AL', 'city': 'FLOMATON'}, 'pop': 3585}
# {'_id': {'state': 'AL', 'city': 'EASTABOGA'}, 'pop': 3999}
# {'_id': {'state': 'AL', 'city': 'TALLADEGA'}, 'pop': 29778}
# {'_id': {'state': 'AL', 'city': 'PIEDMONT'}, 'pop': 12921}
# {'_id': {'state': 'AL', 'city': 'VINCENT'}, 'pop': 295}
# {'_id': {'state': 'AL', 'city': 'HELENA'}, 'pop': 9938}
# {'_id': {'state': 'AL', 'city': 'BUHL'}, 'pop': 1662}
# {'_id': {'state': 'AL', 'city': 'THOMASVILLE'}, 'pop': 6229}
# {'_id': {'state': 'AL', 'city': 'MARION'}, 'pop': 7284}
# {'_id': {'state': 'AL', 'city': 'ANDALUSIA'}, 'pop': 16920}
# {'_id': {'state': 'AL', 'city': 'GOODWATER'}, 'pop': 3813}
# {'_id': {'state': 'AL', 'city': 'STOCKTON'}, 'pop': 1214}
# {'_id': {'state': 'AL', 'city': 'FRISCO CITY'}, 'pop': 6179}
# {'_id': {'state': 'AL', 'city': 'ROCKFORD'}, 'pop': 1819}
# {'_id': {'state': 'AL', 'city': 'HUEYTOWN'}, 'pop': 39677}
# {'_id': {'state': 'AL', 'city': 'WINFIELD'}, 'pop': 6750}
# {'_id': {'state': 'AL', 'city': 'WARRIOR'}, 'pop': 530}
# {'_id': {'state': 'AL', 'city': 'VALHERMOSO SPRIN'}, 'pop': 667}
# {'_id': {'state': 'AL', 'city': 'LOWER PEACH TREE'}, 'pop': 323}
# {'_id': {'state': 'AL', 'city': 'STANTON'}, 'pop': 916}
# {'_id': {'state': 'AL', 'city': 'SNEAD'}, 'pop': 9472}
# {'_id': {'state': 'AL', 'city': 'FRUITDALE'}, 'pop': 848}
# {'_id': {'state': 'AL', 'city': 'NEW HOPE'}, 'pop': 4075}
# {'_id': {'state': 'AL', 'city': 'HARDAWAY'}, 'pop': 354}
# {'_id': {'state': 'AL', 'city': 'BLUFF PARK'}, 'pop': 23992}
# {'_id': {'state': 'AL', 'city': 'DOZIER'}, 'pop': 741}
# {'_id': {'state': 'AL', 'city': 'PHENIX CITY'}, 'pop': 41952}
# {'_id': {'state': 'AL', 'city': 'CHATOM'}, 'pop': 3094}
# {'_id': {'state': 'AL', 'city': 'MENTONE'}, 'pop': 2099}
# {'_id': {'state': 'AL', 'city': 'GORDO'}, 'pop': 4333}
# {'_id': {'state': 'AL', 'city': 'FOSTERS'}, 'pop': 2100}
# {'_id': {'state': 'AL', 'city': 'UNIONTOWN'}, 'pop': 4173}
# {'_id': {'state': 'AL', 'city': 'NEWELL'}, 'pop': 2407}
# {'_id': {'state': 'AL', 'city': 'ADDISON'}, 'pop': 3263}
# {'_id': {'state': 'AL', 'city': 'HUNTSVILLE'}, 'pop': 176118}
# {'_id': {'state': 'AL', 'city': 'COURTLAND'}, 'pop': 2733}
# {'_id': {'state': 'AL', 'city': 'RANDOLPH'}, 'pop': 434}
# {'_id': {'state': 'AL', 'city': 'CLANTON'}, 'pop': 13990}
# {'_id': {'state': 'AL', 'city': 'ARDMORE'}, 'pop': 1898}
# {'_id': {'state': 'AL', 'city': 'NEWVILLE'}, 'pop': 1525}
# {'_id': {'state': 'AL', 'city': 'EVA'}, 'pop': 3977}
# {'_id': {'state': 'AL', 'city': 'ROBERTSDALE'}, 'pop': 3519}
# {'_id': {'state': 'AL', 'city': 'NEWTON'}, 'pop': 1660}
# {'_id': {'state': 'AL', 'city': 'FORT RUCKER'}, 'pop': 7607}
# {'_id': {'state': 'AL', 'city': 'OXFORD'}, 'pop': 12407}
# {'_id': {'state': 'AL', 'city': 'WING'}, 'pop': 1583}
# {'_id': {'state': 'AL', 'city': 'RED BAY'}, 'pop': 5159}
# {'_id': {'state': 'AL', 'city': 'DUTTON'}, 'pop': 2948}
# {'_id': {'state': 'AL', 'city': 'KEYSTONE'}, 'pop': 14218}
# {'_id': {'state': 'AL', 'city': 'MONTGOMERY'}, 'pop': 193811}
# {'_id': {'state': 'AL', 'city': 'ELBA'}, 'pop': 6662}
# {'_id': {'state': 'AL', 'city': 'EQUALITY'}, 'pop': 1121}
# {'_id': {'state': 'AL', 'city': 'PHIL CAMPBELL'}, 'pop': 5345}
# {'_id': {'state': 'AL', 'city': 'BERRY'}, 'pop': 4887}
# {'_id': {'state': 'AL', 'city': 'UNION GROVE'}, 'pop': 4921}
# {'_id': {'state': 'AL', 'city': 'THOMASTON'}, 'pop': 1527}
# {'_id': {'state': 'AL', 'city': 'CENTREVILLE'}, 'pop': 4902}
# {'_id': {'state': 'AL', 'city': 'WEST BLOCTON'}, 'pop': 5276}
# {'_id': {'state': 'AL', 'city': 'DETROIT'}, 'pop': 938}
# {'_id': {'state': 'AL', 'city': 'GILBERTOWN'}, 'pop': 1606}
# {'_id': {'state': 'AL', 'city': 'DELTA'}, 'pop': 1405}
# {'_id': {'state': 'AL', 'city': 'FORT MC CLELLAN'}, 'pop': 4128}
# {'_id': {'state': 'AL', 'city': 'BENTON'}, 'pop': 1396}
# {'_id': {'state': 'AL', 'city': 'MALVERN'}, 'pop': 1686}
# {'_id': {'state': 'AL', 'city': 'BEAVERTON'}, 'pop': 1014}
# {'_id': {'state': 'AL', 'city': 'ODENVILLE'}, 'pop': 1123}
# {'_id': {'state': 'AL', 'city': 'CENTER POINT'}, 'pop': 59735}
# {'_id': {'state': 'AL', 'city': 'GAINESTOWN'}, 'pop': 301}
# {'_id': {'state': 'AL', 'city': 'NAPIER FIELD'}, 'pop': 32407}
# {'_id': {'state': 'AL', 'city': 'BRIDGEPORT'}, 'pop': 3988}
# {'_id': {'state': 'AL', 'city': 'OZARK'}, 'pop': 19017}
# {'_id': {'state': 'AL', 'city': 'EIGHT MILE'}, 'pop': 13517}
# {'_id': {'state': 'AL', 'city': 'BRENT'}, 'pop': 3791}
# {'_id': {'state': 'AL', 'city': 'WAVERLY'}, 'pop': 1689}
# {'_id': {'state': 'AL', 'city': 'MIDLAND CITY'}, 'pop': 4854}
# {'_id': {'state': 'AL', 'city': 'JACKSONS GAP'}, 'pop': 2236}
# {'_id': {'state': 'AL', 'city': 'GALLION'}, 'pop': 599}
# {'_id': {'state': 'AL', 'city': 'HARTSELLE'}, 'pop': 17963}
# {'_id': {'state': 'AL', 'city': 'HAZEL GREEN'}, 'pop': 7751}
# {'_id': {'state': 'AL', 'city': 'ATMORE'}, 'pop': 15948}
# {'_id': {'state': 'AL', 'city': 'THORSBY'}, 'pop': 4131}
# {'_id': {'state': 'AL', 'city': 'HOLT'}, 'pop': 21997}
# {'_id': {'state': 'AL', 'city': 'HYTOP'}, 'pop': 16934}
# {'_id': {'state': 'AL', 'city': 'ECLECTIC'}, 'pop': 6105}
# {'_id': {'state': 'AL', 'city': 'BIGBEE'}, 'pop': 264}
# {'_id': {'state': 'AL', 'city': 'HANCEVILLE'}, 'pop': 10186}
# {'_id': {'state': 'AL', 'city': 'DAVISTON'}, 'pop': 2334}
# {'_id': {'state': 'AL', 'city': 'FITZPATRICK'}, 'pop': 736}
# {'_id': {'state': 'AL', 'city': 'PANSEY'}, 'pop': 595}
# {'_id': {'state': 'AL', 'city': 'LOXLEY'}, 'pop': 2712}
# {'_id': {'state': 'AL', 'city': 'AUBURN'}, 'pop': 38908}
# {'_id': {'state': 'AL', 'city': 'CHICKASAW'}, 'pop': 6660}
# {'_id': {'state': 'AL', 'city': 'TIBBIE'}, 'pop': 327}
# {'_id': {'state': 'AL', 'city': 'CYPRESS'}, 'pop': 2659}
# {'_id': {'state': 'AL', 'city': 'DAWSON'}, 'pop': 1531}
# {'_id': {'state': 'AL', 'city': 'DADEVILLE'}, 'pop': 7620}
# {'_id': {'state': 'AL', 'city': 'MOUNT HOPE'}, 'pop': 1821}
# {'_id': {'state': 'AL', 'city': 'FALKVILLE'}, 'pop': 5392}
# {'_id': {'state': 'AL', 'city': 'WATERLOO'}, 'pop': 1899}
# {'_id': {'state': 'AL', 'city': 'GORDON'}, 'pop': 2017}
# {'_id': {'state': 'AL', 'city': 'GROVEOAK'}, 'pop': 1098}
# {'_id': {'state': 'AL', 'city': 'CEDAR BLUFF'}, 'pop': 3574}
# {'_id': {'state': 'AL', 'city': 'SEALE'}, 'pop': 1949}
# {'_id': {'state': 'AL', 'city': 'BANKSTON'}, 'pop': 651}
# {'_id': {'state': 'AL', 'city': 'ALDEN'}, 'pop': 4429}
# {'_id': {'state': 'AL', 'city': 'DIXIANA'}, 'pop': 17068}
# {'_id': {'state': 'AL', 'city': 'ALPINE'}, 'pop': 3062}
# {'_id': {'state': 'AL', 'city': 'GOSHEN'}, 'pop': 2056}
# {'_id': {'state': 'AL', 'city': 'FORT MORGAN'}, 'pop': 4930}
# {'_id': {'state': 'AL', 'city': 'MAGNOLIA'}, 'pop': 222}
# {'_id': {'state': 'AL', 'city': 'SPROTT'}, 'pop': 1191}
# {'_id': {'state': 'AL', 'city': 'PETERMAN'}, 'pop': 1826}
# {'_id': {'state': 'AL', 'city': 'WELLINGTON'}, 'pop': 2137}
# {'_id': {'state': 'AL', 'city': 'PINE APPLE'}, 'pop': 1658}
# {'_id': {'state': 'AL', 'city': 'ARLINGTON'}, 'pop': 1098}
# {'_id': {'state': 'AL', 'city': 'BRUNDIDGE'}, 'pop': 4320}
# {'_id': {'state': 'AL', 'city': 'WETUMPKA'}, 'pop': 13725}
# {'_id': {'state': 'AL', 'city': 'TALLASSEE'}, 'pop': 12046}
# {'_id': {'state': 'AL', 'city': 'PRATTVILLE'}, 'pop': 27595}
# {'_id': {'state': 'AL', 'city': 'NEW SITE'}, 'pop': 19942}
# {'_id': {'state': 'AL', 'city': 'LAFAYETTE'}, 'pop': 7045}
# {'_id': {'state': 'AL', 'city': 'ALICEVILLE'}, 'pop': 5196}
# {'_id': {'state': 'AL', 'city': 'NAUVOO'}, 'pop': 5004}
# {'_id': {'state': 'AL', 'city': 'PELL CITY'}, 'pop': 17981}
# {'_id': {'state': 'AL', 'city': 'MOULTON'}, 'pop': 17288}
# {'_id': {'state': 'AL', 'city': 'HONORAVILLE'}, 'pop': 838}
# {'_id': {'state': 'AL', 'city': 'MILLRY'}, 'pop': 2825}
# {'_id': {'state': 'AL', 'city': 'HEFLIN'}, 'pop': 6577}
# {'_id': {'state': 'AL', 'city': 'KENNEDY'}, 'pop': 3618}
# {'_id': {'state': 'AL', 'city': 'FAIRHOPE'}, 'pop': 16331}
# {'_id': {'state': 'AL', 'city': 'CROPWELL'}, 'pop': 4171}
# {'_id': {'state': 'AL', 'city': 'SARDIS'}, 'pop': 1683}
# {'_id': {'state': 'AL', 'city': 'SECTION'}, 'pop': 2590}
# {'_id': {'state': 'AL', 'city': 'CLOPTON'}, 'pop': 157}
# {'_id': {'state': 'AL', 'city': 'BUTLER'}, 'pop': 4957}
# {'_id': {'state': 'AL', 'city': 'BURKVILLE'}, 'pop': 1478}
# {'_id': {'state': 'AL', 'city': 'RAINSVILLE'}, 'pop': 7498}
# {'_id': {'state': 'AL', 'city': 'VESTAVIA HILLS'}, 'pop': 29224}
# {'_id': {'state': 'AL', 'city': 'KIMBERLY'}, 'pop': 1045}
# {'_id': {'state': 'AL', 'city': 'AXIS'}, 'pop': 140}
# {'_id': {'state': 'AL', 'city': 'ASHFORD'}, 'pop': 5115}
# {'_id': {'state': 'AL', 'city': 'TONEY'}, 'pop': 5953}
# {'_id': {'state': 'AL', 'city': 'MARBURY'}, 'pop': 3573}
# {'_id': {'state': 'AL', 'city': 'MORRIS'}, 'pop': 3622}
# {'_id': {'state': 'AL', 'city': 'COTTONWOOD'}, 'pop': 8517}
# {'_id': {'state': 'AL', 'city': 'PAINT ROCK'}, 'pop': 553}
# {'_id': {'state': 'AL', 'city': 'BIG COVE'}, 'pop': 3156}
# {'_id': {'state': 'AL', 'city': 'GERALDINE'}, 'pop': 3291}
# {'_id': {'state': 'AL', 'city': 'BEAR CREEK'}, 'pop': 3748}
# {'_id': {'state': 'AL', 'city': 'COATOPA'}, 'pop': 6055}
# {'_id': {'state': 'AL', 'city': 'HOKES BLUFF'}, 'pop': 20057}
# {'_id': {'state': 'AL', 'city': 'CARBON HILL'}, 'pop': 3597}
# {'_id': {'state': 'AL', 'city': 'VERBENA'}, 'pop': 3702}
# {'_id': {'state': 'AL', 'city': 'CULLMAN'}, 'pop': 31708}
# {'_id': {'state': 'AL', 'city': 'SALEM'}, 'pop': 2773}
# {'_id': {'state': 'AL', 'city': 'HAMILTON'}, 'pop': 11184}
# {'_id': {'state': 'AL', 'city': 'MAPLESVILLE'}, 'pop': 1995}
# {'_id': {'state': 'AL', 'city': 'NEW BROCKTON'}, 'pop': 1809}
# {'_id': {'state': 'AL', 'city': 'BAY MINETTE'}, 'pop': 17816}
# {'_id': {'state': 'AL', 'city': 'EUTAW'}, 'pop': 6586}
# {'_id': {'state': 'AL', 'city': 'ELBERTA'}, 'pop': 2551}
# {'_id': {'state': 'AL', 'city': 'TUSCALOOSA'}, 'pop': 78365}
# {'_id': {'state': 'AL', 'city': 'FAIRFIELD'}, 'pop': 12106}
# {'_id': {'state': 'AL', 'city': 'LEXINGTON'}, 'pop': 2241}
# {'_id': {'state': 'AL', 'city': 'RED LEVEL'}, 'pop': 2005}
# {'_id': {'state': 'AL', 'city': 'HATCHECHUBBEE'}, 'pop': 772}
# {'_id': {'state': 'AL', 'city': 'ORANGE BEACH'}, 'pop': 2549}
# {'_id': {'state': 'AL', 'city': 'LANETT'}, 'pop': 12083}
# {'_id': {'state': 'AL', 'city': 'FORT PAYNE'}, 'pop': 15893}
# {'_id': {'state': 'AL', 'city': 'GALLANT'}, 'pop': 337}
# {'_id': {'state': 'AL', 'city': 'FACKLER'}, 'pop': 396}
# {'_id': {'state': 'AL', 'city': 'TRIANA'}, 'pop': 24398}
# {'_id': {'state': 'AL', 'city': 'HOPE HULL'}, 'pop': 2961}
# {'_id': {'state': 'AL', 'city': 'RAMER'}, 'pop': 1712}
# {'_id': {'state': 'AL', 'city': 'GREENVILLE'}, 'pop': 15476}
# {'_id': {'state': 'AL', 'city': 'JEMISON'}, 'pop': 7202}
# {'_id': {'state': 'AL', 'city': 'GAYLESVILLE'}, 'pop': 2291}
# {'_id': {'state': 'AL', 'city': 'COOSA PINES'}, 'pop': 7985}
# {'_id': {'state': 'AL', 'city': 'MUSCLE SHOALS'}, 'pop': 11777}
# {'_id': {'state': 'AL', 'city': 'KINSTON'}, 'pop': 3523}
# {'_id': {'state': 'AL', 'city': 'HOLLYWOOD'}, 'pop': 2038}
# {'_id': {'state': 'AL', 'city': 'PRAIRIE'}, 'pop': 112}
# {'_id': {'state': 'AL', 'city': 'CREOLA'}, 'pop': 2569}
# {'_id': {'state': 'AL', 'city': 'WARD'}, 'pop': 274}
# {'_id': {'state': 'AL', 'city': 'ATHENS'}, 'pop': 35441}
# {'_id': {'state': 'AL', 'city': 'HOLLY POND'}, 'pop': 3838}
# {'_id': {'state': 'AL', 'city': 'PERDIDO'}, 'pop': 986}
# {'_id': {'state': 'AL', 'city': 'QUINTON'}, 'pop': 2198}
# {'_id': {'state': 'AL', 'city': 'PLANTERSVILLE'}, 'pop': 946}
# {'_id': {'state': 'AL', 'city': 'KELLYTON'}, 'pop': 1584}
# {'_id': {'state': 'AL', 'city': 'BESSEMER'}, 'pop': 40549}
# {'_id': {'state': 'AL', 'city': 'HIGDON'}, 'pop': 1324}
# {'_id': {'state': 'AL', 'city': 'NORTHPORT'}, 'pop': 20114}
# {'_id': {'state': 'AL', 'city': 'ALEXANDRIA'}, 'pop': 5776}
# {'_id': {'state': 'AL', 'city': 'BLACK'}, 'pop': 183}
# {'_id': {'state': 'AL', 'city': 'SUMMERDALE'}, 'pop': 881}
# {'_id': {'state': 'AL', 'city': 'HOOVER'}, 'pop': 9758}
# {'_id': {'state': 'AL', 'city': 'ECHOLA'}, 'pop': 223}
# {'_id': {'state': 'AL', 'city': 'NEW MARKET'}, 'pop': 5825}
# {'_id': {'state': 'AL', 'city': 'ALLEN'}, 'pop': 0}
# {'_id': {'state': 'AL', 'city': 'COTTONDALE'}, 'pop': 4727}
# {'_id': {'state': 'AL', 'city': 'MOBILE'}, 'pop': 235452}
# {'_id': {'state': 'AL', 'city': 'JACHIN'}, 'pop': 480}
# {'_id': {'state': 'AL', 'city': 'SYLACAUGA'}, 'pop': 24424}
# {'_id': {'state': 'AL', 'city': 'AUTAUGAVILLE'}, 'pop': 2641}
# {'_id': {'state': 'AL', 'city': 'SATSUMA'}, 'pop': 6197}
# {'_id': {'state': 'AL', 'city': 'WAGARVILLE'}, 'pop': 1681}
# {'_id': {'state': 'AL', 'city': 'ANDERSON'}, 'pop': 2039}
# {'_id': {'state': 'AL', 'city': 'NEWBERN'}, 'pop': 1131}
# {'_id': {'state': 'AL', 'city': 'RIVERSIDE'}, 'pop': 1004}
# {'_id': {'state': 'AL', 'city': 'IRVINGTON'}, 'pop': 6181}
# {'_id': {'state': 'AL', 'city': 'SMITHS'}, 'pop': 10605}
# {'_id': {'state': 'AL', 'city': 'DECATUR'}, 'pop': 54557}
# {'_id': {'state': 'AL', 'city': 'HARVEST'}, 'pop': 5701}
# {'_id': {'state': 'AL', 'city': 'RALPH'}, 'pop': 927}
# {'_id': {'state': 'AL', 'city': 'CECIL'}, 'pop': 407}
# {'_id': {'state': 'AL', 'city': 'HACKLEBURG'}, 'pop': 2828}
# {'_id': {'state': 'AL', 'city': 'WHATLEY'}, 'pop': 790}
# {'_id': {'state': 'AL', 'city': 'LAWLEY'}, 'pop': 337}
# {'_id': {'state': 'AL', 'city': 'CORDOVA'}, 'pop': 5273}
# {'_id': {'state': 'AL', 'city': 'MATHEWS'}, 'pop': 836}
# {'_id': {'state': 'AL', 'city': 'LEEDS'}, 'pop': 10421}
# {'_id': {'state': 'AL', 'city': 'CHELSEA'}, 'pop': 4781}
# {'_id': {'state': 'AL', 'city': 'STEELE'}, 'pop': 1830}
# {'_id': {'state': 'AL', 'city': 'GUNTER AFS'}, 'pop': 1348}
# {'_id': {'state': 'AL', 'city': 'CUBA'}, 'pop': 1184}
# {'_id': {'state': 'AL', 'city': 'PIKE ROAD'}, 'pop': 3398}
# {'_id': {'state': 'AL', 'city': 'TUSKEGEE'}, 'pop': 10687}
# {'_id': {'state': 'AL', 'city': 'WILSONVILLE'}, 'pop': 5224}
# {'_id': {'state': 'AL', 'city': 'DALEVILLE'}, 'pop': 8885}
# {'_id': {'state': 'AL', 'city': 'DEER PARK'}, 'pop': 723}
# {'_id': {'state': 'AL', 'city': 'JONES'}, 'pop': 428}
# {'_id': {'state': 'AL', 'city': 'DAUPHIN ISLAND'}, 'pop': 824}
# {'_id': {'state': 'AL', 'city': 'DEATSVILLE'}, 'pop': 5913}
# {'_id': {'state': 'AL', 'city': 'SHORTER'}, 'pop': 1876}
# {'_id': {'state': 'AL', 'city': 'GAINESVILLE'}, 'pop': 1051}
# {'_id': {'state': 'AL', 'city': 'MAXWELL A F B'}, 'pop': 2788}
# {'_id': {'state': 'AL', 'city': 'DANVILLE'}, 'pop': 4614}
# {'_id': {'state': 'AL', 'city': 'CENTRE'}, 'pop': 10294}
# {'_id': {'state': 'AL', 'city': 'UNION SPRINGS'}, 'pop': 7555}
# {'_id': {'state': 'AL', 'city': 'BEATRICE'}, 'pop': 1620}
# {'_id': {'state': 'AL', 'city': 'ROGERSVILLE'}, 'pop': 6521}
# {'_id': {'state': 'AL', 'city': 'JACK'}, 'pop': 1517}
# {'_id': {'state': 'AL', 'city': 'CARLTON'}, 'pop': 30}
# {'_id': {'state': 'AL', 'city': 'WADLEY'}, 'pop': 1949}
# {'_id': {'state': 'AL', 'city': 'GADSDEN'}, 'pop': 7002}
# {'_id': {'state': 'AL', 'city': 'CASTLEBERRY'}, 'pop': 2881}
# {'_id': {'state': 'AL', 'city': 'SAMSON'}, 'pop': 4790}
# {'_id': {'state': 'AL', 'city': 'SPRINGVILLE'}, 'pop': 8723}
# {'_id': {'state': 'AL', 'city': 'MAYLENE'}, 'pop': 3727}
# {'_id': {'state': 'AL', 'city': 'DICKINSON'}, 'pop': 272}
# {'_id': {'state': 'AL', 'city': 'SOUTHSIDE'}, 'pop': 44165}
# {'_id': {'state': 'AL', 'city': 'HILLSBORO'}, 'pop': 1967}
# {'_id': {'state': 'AL', 'city': 'LOUISVILLE'}, 'pop': 2279}
# {'_id': {'state': 'AL', 'city': 'ETHELSVILLE'}, 'pop': 719}
# {'_id': {'state': 'AL', 'city': 'RUTLEDGE'}, 'pop': 1976}
# {'_id': {'state': 'AL', 'city': 'MOUNTAIN BROOK'}, 'pop': 11117}
# {'_id': {'state': 'AL', 'city': 'NEEDHAM'}, 'pop': 618}
# {'_id': {'state': 'AL', 'city': 'ORRVILLE'}, 'pop': 2680}
# {'_id': {'state': 'AL', 'city': 'WALKER SPRINGS'}, 'pop': 1001}
# {'_id': {'state': 'AL', 'city': 'TAYLOR'}, 'pop': 32689}
# {'_id': {'state': 'AL', 'city': 'SELMA'}, 'pop': 39500}
# {'_id': {'state': 'AL', 'city': 'BRYANT'}, 'pop': 1700}
# {'_id': {'state': 'AL', 'city': 'ELDRIDGE'}, 'pop': 421}
# {'_id': {'state': 'AL', 'city': 'ROCK MILLS'}, 'pop': 9430}
# {'_id': {'state': 'AL', 'city': 'RUSSELLVILLE'}, 'pop': 17767}
# {'_id': {'state': 'AL', 'city': 'FRANKVILLE'}, 'pop': 472}
# {'_id': {'state': 'AL', 'city': 'SEMINOLE'}, 'pop': 606}
# {'_id': {'state': 'AL', 'city': 'PARRISH'}, 'pop': 4775}
# {'_id': {'state': 'AL', 'city': 'HAYNEVILLE'}, 'pop': 5010}
# {'_id': {'state': 'AL', 'city': 'GRANT'}, 'pop': 8345}
# {'_id': {'state': 'AL', 'city': 'FOREST HOME'}, 'pop': 1528}
# {'_id': {'state': 'AL', 'city': 'FORT DAVIS'}, 'pop': 891}
# {'_id': {'state': 'AL', 'city': 'TANNER'}, 'pop': 2578}
# {'_id': {'state': 'AL', 'city': 'TUSKEGEE INSTITU'}, 'pop': 6915}
# {'_id': {'state': 'AL', 'city': 'WOODLAND'}, 'pop': 2291}
# {'_id': {'state': 'AL', 'city': 'ADAMSVILLE'}, 'pop': 10616}
# {'_id': {'state': 'AL', 'city': 'OPP'}, 'pop': 9901}
# {'_id': {'state': 'AL', 'city': 'PITTSVIEW'}, 'pop': 1525}
# {'_id': {'state': 'AL', 'city': 'SPANISH FORT'}, 'pop': 5486}
# {'_id': {'state': 'AL', 'city': 'OPELIKA'}, 'pop': 32808}
# {'_id': {'state': 'AL', 'city': 'BROWNSBORO'}, 'pop': 1793}
# {'_id': {'state': 'AL', 'city': 'TOWN CREEK'}, 'pop': 9049}
# {'_id': {'state': 'AL', 'city': 'VANCE'}, 'pop': 1234}
# {'_id': {'state': 'AL', 'city': 'ASHLAND'}, 'pop': 4518}
# {'_id': {'state': 'AL', 'city': 'ARLEY'}, 'pop': 2645}
# {'_id': {'state': 'AL', 'city': 'GUIN'}, 'pop': 3948}
# {'_id': {'state': 'AL', 'city': 'ABBEVILLE'}, 'pop': 5416}
# {'_id': {'state': 'AL', 'city': 'BREMEN'}, 'pop': 3448}
# {'_id': {'state': 'AL', 'city': 'EPES'}, 'pop': 1391}
# {'_id': {'state': 'AL', 'city': 'DAPHNE'}, 'pop': 14607}
# {'_id': {'state': 'AL', 'city': 'COALBURG'}, 'pop': 5909}
# {'_id': {'state': 'AL', 'city': 'BANKS'}, 'pop': 1857}
# {'_id': {'state': 'AL', 'city': 'BAYOU LA BATRE'}, 'pop': 4901}
# {'_id': {'state': 'AL', 'city': 'HALEYVILLE'}, 'pop': 9141}
# {'_id': {'state': 'AL', 'city': 'INDIAN SPRINGS'}, 'pop': 7412}
# {'_id': {'state': 'AL', 'city': 'HURTSBORO'}, 'pop': 1727}
# {'_id': {'state': 'AL', 'city': 'VERNON'}, 'pop': 4752}
# {'_id': {'state': 'AL', 'city': 'CRANE HILL'}, 'pop': 2270}
# {'_id': {'state': 'AL', 'city': 'LISMAN'}, 'pop': 2313}
# {'_id': {'state': 'AL', 'city': 'FULTON'}, 'pop': 2163}
# {'_id': {'state': 'AL', 'city': 'SWEET WATER'}, 'pop': 2444}
# {'_id': {'state': 'AL', 'city': 'SHOAL CREEK'}, 'pop': 16228}
# {'_id': {'state': 'AL', 'city': 'SYLVANIA'}, 'pop': 2318}
# {'_id': {'state': 'AL', 'city': 'TOXEY'}, 'pop': 1980}
# {'_id': {'state': 'AL', 'city': 'ARITON'}, 'pop': 1434}
# {'_id': {'state': 'AL', 'city': 'LEIGHTON'}, 'pop': 3046}
# {'_id': {'state': 'AL', 'city': 'TOWNLEY'}, 'pop': 1819}
# {'_id': {'state': 'AL', 'city': 'DORA'}, 'pop': 11017}
# {'_id': {'state': 'AL', 'city': 'WEDOWEE'}, 'pop': 3101}
# {'_id': {'state': 'AL', 'city': 'WEAVER'}, 'pop': 7453}
# {'_id': {'state': 'AL', 'city': 'DUNCANVILLE'}, 'pop': 5514}
# {'_id': {'state': 'AL', 'city': 'HIGHLAND HOME'}, 'pop': 3068}
# {'_id': {'state': 'AL', 'city': 'TRAFFORD'}, 'pop': 909}
# {'_id': {'state': 'AL', 'city': 'PLEASANT GROVE'}, 'pop': 8458}
# {'_id': {'state': 'AL', 'city': 'MC CALLA'}, 'pop': 8147}
# {'_id': {'state': 'AL', 'city': 'VREDENBURGH'}, 'pop': 2040}
# {'_id': {'state': 'AL', 'city': 'STEWART'}, 'pop': 1745}
# {'_id': {'state': 'AL', 'city': 'STERRETT'}, 'pop': 617}
# {'_id': {'state': 'AL', 'city': 'CUSSETA'}, 'pop': 4597}
# {'_id': {'state': 'AL', 'city': 'ANNISTON'}, 'pop': 49285}
# {'_id': {'state': 'AL', 'city': 'LINDEN'}, 'pop': 5438}
# {'_id': {'state': 'AL', 'city': 'JACKSON'}, 'pop': 9679}
# {'_id': {'state': 'AL', 'city': 'GENEVA'}, 'pop': 5471}
# {'_id': {'state': 'AL', 'city': 'BLOUNTSVILLE'}, 'pop': 9058}
# {'_id': {'state': 'AL', 'city': 'COFFEEVILLE'}, 'pop': 1374}
# {'_id': {'state': 'AL', 'city': 'MOUNT VERNON'}, 'pop': 5053}
# {'_id': {'state': 'AL', 'city': 'WOODSTOCK'}, 'pop': 691}
# {'_id': {'state': 'AL', 'city': 'COFFEE SPRINGS'}, 'pop': 750}
# {'_id': {'state': 'AL', 'city': 'ELROD'}, 'pop': 809}
# {'_id': {'state': 'AL', 'city': 'SEMMES'}, 'pop': 9329}
# {'_id': {'state': 'AL', 'city': 'COLLINSVILLE'}, 'pop': 3245}
# {'_id': {'state': 'AL', 'city': 'CALERA'}, 'pop': 4675}
# {'_id': {'state': 'AL', 'city': 'FLORENCE'}, 'pop': 55203}
# {'_id': {'state': 'AL', 'city': 'EMELLE'}, 'pop': 491}
# {'_id': {'state': 'AL', 'city': 'LANGSTON'}, 'pop': 1041}
# {'_id': {'state': 'AL', 'city': 'ADGER'}, 'pop': 3205}
# {'_id': {'state': 'AL', 'city': 'IDER'}, 'pop': 5161}
# {'_id': {'state': 'AL', 'city': 'MILLBROOK'}, 'pop': 9049}
# {'_id': {'state': 'AL', 'city': 'EMPIRE'}, 'pop': 2429}
# {'_id': {'state': 'AL', 'city': 'JOPPA'}, 'pop': 987}
# {'_id': {'state': 'AL', 'city': 'MIDWAY'}, 'pop': 1873}
# {'_id': {'state': 'AL', 'city': 'DOLOMITE'}, 'pop': 1476}
# {'_id': {'state': 'AL', 'city': 'MONTEVALLO'}, 'pop': 11638}
# {'_id': {'state': 'AL', 'city': 'TRINITY'}, 'pop': 1758}
# {'_id': {'state': 'AL', 'city': 'SARALAND'}, 'pop': 13151}
# {'_id': {'state': 'AL', 'city': 'COKER'}, 'pop': 5747}
# {'_id': {'state': 'AL', 'city': 'GANTT'}, 'pop': 3298}
# {'_id': {'state': 'AL', 'city': 'FAUNSDALE'}, 'pop': 831}
# {'_id': {'state': 'AL', 'city': 'HAYDEN'}, 'pop': 6533}
# {'_id': {'state': 'AL', 'city': 'SHEFFIELD'}, 'pop': 10685}
# {'_id': {'state': 'AL', 'city': 'TROY'}, 'pop': 19358}
# {'_id': {'state': 'AL', 'city': 'MORVIN'}, 'pop': 24}
# {'_id': {'state': 'AL', 'city': 'CRESTLINE HEIGHT'}, 'pop': 13191}
# {'_id': {'state': 'AL', 'city': 'ALBERTVILLE'}, 'pop': 21033}
# {'_id': {'state': 'AL', 'city': 'MUNFORD'}, 'pop': 4998}
# {'_id': {'state': 'AL', 'city': 'MILLERVILLE'}, 'pop': 863}
# {'_id': {'state': 'AL', 'city': 'ATTALLA'}, 'pop': 11904}
# {'_id': {'state': 'AL', 'city': 'HOUSTON'}, 'pop': 429}
# {'_id': {'state': 'AL', 'city': 'YORK'}, 'pop': 5728}
# {'_id': {'state': 'AL', 'city': 'ASHVILLE'}, 'pop': 5988}
# {'_id': {'state': 'AL', 'city': 'TITUS'}, 'pop': 2683}
# {'_id': {'state': 'AL', 'city': 'BRANTLEY'}, 'pop': 2623}
# {'_id': {'state': 'AL', 'city': 'BRILLIANT'}, 'pop': 2515}
# {'_id': {'state': 'AL', 'city': 'CROSSVILLE'}, 'pop': 4874}
# {'_id': {'state': 'AL', 'city': 'WILMER'}, 'pop': 5905}
# {'_id': {'state': 'AL', 'city': 'HOLLYTREE'}, 'pop': 260}
# {'_id': {'state': 'AL', 'city': 'ALBERTA'}, 'pop': 1340}
# {'_id': {'state': 'AL', 'city': 'URIAH'}, 'pop': 1648}
# {'_id': {'state': 'AL', 'city': 'NOTASULGA'}, 'pop': 3361}
# {'_id': {'state': 'AL', 'city': 'SYLVAN SPRINGS'}, 'pop': 3948}
# {'_id': {'state': 'AL', 'city': 'BOYS RANCH'}, 'pop': 1714}
# {'_id': {'state': 'AL', 'city': 'TRUSSVILLE'}, 'pop': 13367}
# {'_id': {'state': 'AL', 'city': 'EVERGREEN'}, 'pop': 8556}
# {'_id': {'state': 'AL', 'city': 'SULLIGENT'}, 'pop': 4489}
# {'_id': {'state': 'AL', 'city': 'KILLEN'}, 'pop': 11758}
# {'_id': {'state': 'AL', 'city': 'VANDIVER'}, 'pop': 1066}
# {'_id': {'state': 'AL', 'city': 'MC INTOSH'}, 'pop': 4211}
# {'_id': {'state': 'AL', 'city': 'SOMERVILLE'}, 'pop': 5184}
# {'_id': {'state': 'AL', 'city': 'MILLPORT'}, 'pop': 2286}
# {'_id': {'state': 'AL', 'city': 'FRUITHURST'}, 'pop': 1473}
# {'_id': {'state': 'AL', 'city': 'GRAND BAY'}, 'pop': 10344}
# {'_id': {'state': 'AL', 'city': 'SAFFORD'}, 'pop': 715}
# {'_id': {'state': 'AL', 'city': 'EUFAULA'}, 'pop': 16858}
# {'_id': {'state': 'AL', 'city': 'MC KENZIE'}, 'pop': 1222}
# {'_id': {'state': 'AL', 'city': 'SHORTERVILLE'}, 'pop': 2503}
# {'_id': {'state': 'AL', 'city': 'CLIO'}, 'pop': 3178}
# {'_id': {'state': 'AL', 'city': 'MIDFIELD'}, 'pop': 9294}
# {'_id': {'state': 'AL', 'city': 'DOUBLE SPRINGS'}, 'pop': 4797}
# {'_id': {'state': 'AL', 'city': 'FYFFE'}, 'pop': 3453}
# {'_id': {'state': 'AL', 'city': 'IRONDALE'}, 'pop': 15047}
# {'_id': {'state': 'AL', 'city': 'RANBURNE'}, 'pop': 3696}
# {'_id': {'state': 'AL', 'city': 'BROOKLEY FIELD'}, 'pop': 864}
# {'_id': {'state': 'AL', 'city': 'HORTON'}, 'pop': 4195}
# {'_id': {'state': 'AL', 'city': 'BOLIGEE'}, 'pop': 1073}
# {'_id': {'state': 'AL', 'city': 'SILVERHILL'}, 'pop': 8001}
# {'_id': {'state': 'AL', 'city': 'BIRMINGHAM'}, 'pop': 242606}
# {'_id': {'state': 'AL', 'city': 'LACEYS SPRING'}, 'pop': 7040}
# {'_id': {'state': 'AL', 'city': 'VINEGAR BEND'}, 'pop': 475}
# {'_id': {'state': 'AL', 'city': 'FIVE POINTS'}, 'pop': 2400}
# {'_id': {'state': 'AL', 'city': 'COY'}, 'pop': 1109}
# {'_id': {'state': 'AL', 'city': 'REPTON'}, 'pop': 1750}
# {'_id': {'state': 'AL', 'city': 'SPRUCE PINE'}, 'pop': 465}
# {'_id': {'state': 'AL', 'city': 'CAMDEN'}, 'pop': 4948}
# {'_id': {'state': 'AL', 'city': 'SILAS'}, 'pop': 2600}
# {'_id': {'state': 'AL', 'city': 'ENTERPRISE'}, 'pop': 29102}
# {'_id': {'state': 'AL', 'city': 'RANGE'}, 'pop': 208}
# {'_id': {'state': 'AL', 'city': 'SHELBY'}, 'pop': 1846}
# {'_id': {'state': 'AL', 'city': 'MOUNT OLIVE'}, 'pop': 3841}
# {'_id': {'state': 'AL', 'city': 'REMLAP'}, 'pop': 6013}
# {'_id': {'state': 'AL', 'city': 'GURLEY'}, 'pop': 4642}
# {'_id': {'state': 'AL', 'city': 'VINA'}, 'pop': 888}
# {'_id': {'state': 'AL', 'city': 'GLENCOE'}, 'pop': 4256}
# {'_id': {'state': 'AL', 'city': 'JASPER'}, 'pop': 30600}
# {'_id': {'state': 'AL', 'city': 'LILLIAN'}, 'pop': 3833}
# {'_id': {'state': 'AL', 'city': 'EAST BREWTON'}, 'pop': 15479}
# {'_id': {'state': 'AL', 'city': 'MUSCADINE'}, 'pop': 265}
# {'_id': {'state': 'AL', 'city': 'VINEMONT'}, 'pop': 8852}
# {'_id': {'state': 'AL', 'city': 'ELMORE'}, 'pop': 3114}
# {'_id': {'state': 'AL', 'city': 'ACMAR'}, 'pop': 6055}
# {'_id': {'state': 'AL', 'city': 'CARROLLTON'}, 'pop': 5007}
# {'_id': {'state': 'AL', 'city': 'FOLEY'}, 'pop': 8520}
# {'_id': {'state': 'AL', 'city': 'LAPINE'}, 'pop': 338}
# {'_id': {'state': 'AL', 'city': 'CATHERINE'}, 'pop': 366}
# {'_id': {'state': 'AL', 'city': 'PINE HILL'}, 'pop': 2623}
# {'_id': {'state': 'AL', 'city': 'BROOKWOOD'}, 'pop': 2319}
# {'_id': {'state': 'AL', 'city': 'FORT DEPOSIT'}, 'pop': 2435}
# {'_id': {'state': 'AL', 'city': 'SAINT STEPHENS'}, 'pop': 688}
# {'_id': {'state': 'AL', 'city': 'GREENSBORO'}, 'pop': 7680}
# {'_id': {'state': 'AL', 'city': 'HOMEWOOD'}, 'pop': 24973}
# {'_id': {'state': 'AL', 'city': 'BRIERFIELD'}, 'pop': 1282}
# {'_id': {'state': 'AL', 'city': 'TUSCUMBIA'}, 'pop': 17880}
# {'_id': {'state': 'AL', 'city': 'LITTLE RIVER'}, 'pop': 649}
# {'_id': {'state': 'AL', 'city': 'GEORGIANA'}, 'pop': 3672}
# {'_id': {'state': 'AL', 'city': 'FRANKLIN'}, 'pop': 154}
# {'_id': {'state': 'AL', 'city': 'DEMOPOLIS'}, 'pop': 9992}
# {'_id': {'state': 'AL', 'city': 'PRINCETON'}, 'pop': 273}
# {'_id': {'state': 'AL', 'city': 'OHATCHEE'}, 'pop': 3369}
# {'_id': {'state': 'AL', 'city': 'SLOCOMB'}, 'pop': 4504}
# {'_id': {'state': 'AL', 'city': 'CITRONELLE'}, 'pop': 7233}
# {'_id': {'state': 'AL', 'city': 'CAHABA HEIGHTS'}, 'pop': 13091}
# {'_id': {'state': 'AL', 'city': 'LOGAN'}, 'pop': 2379}
# {'_id': {'state': 'AL', 'city': 'SAWYERVILLE'}, 'pop': 1684}
# {'_id': {'state': 'AL', 'city': 'GRAHAM'}, 'pop': 374}
# {'_id': {'state': 'AL', 'city': 'BILLINGSLEY'}, 'pop': 1869}
# {'_id': {'state': 'AL', 'city': 'WEBB'}, 'pop': 1810}
# {'_id': {'state': 'AL', 'city': 'SKIPPERVILLE'}, 'pop': 1048}
# {'_id': {'state': 'AL', 'city': 'CHANCELLOR'}, 'pop': 620}
# {'_id': {'state': 'AL', 'city': 'ESTILLFORK'}, 'pop': 718}
# {'_id': {'state': 'AL', 'city': 'CRAGFORD'}, 'pop': 796}
# {'_id': {'state': 'AL', 'city': 'CODEN'}, 'pop': 3897}
# {'_id': {'state': 'AL', 'city': 'ONEONTA'}, 'pop': 8956}
# {'_id': {'state': 'AL', 'city': 'COLUMBIANA'}, 'pop': 4486}
# {'_id': {'state': 'AL', 'city': 'ELKMONT'}, 'pop': 8013}
# {'_id': {'state': 'AL', 'city': 'GUNTERSVILLE'}, 'pop': 11234}
# {'_id': {'state': 'AL', 'city': 'PEROTE'}, 'pop': 1792}
# {'_id': {'state': 'AL', 'city': 'GARDENDALE'}, 'pop': 17968}
# {'_id': {'state': 'AL', 'city': 'GLENWOOD'}, 'pop': 109}
# {'_id': {'state': 'AL', 'city': 'FORKLAND'}, 'pop': 2121}
# {'_id': {'state': 'AL', 'city': 'KNOXVILLE'}, 'pop': 373}
# {'_id': {'state': 'AL', 'city': 'WOODVILLE'}, 'pop': 2222}
# {'_id': {'state': 'AL', 'city': 'CLAYTON'}, 'pop': 3106}
# {'_id': {'state': 'AL', 'city': 'ARAB'}, 'pop': 13650}
# {'_id': {'state': 'AL', 'city': 'HARTFORD'}, 'pop': 4819}
# {'_id': {'state': 'AL', 'city': 'LINEVILLE'}, 'pop': 4345}
# {'_id': {'state': 'AL', 'city': 'FLORALA'}, 'pop': 3421}
# {'_id': {'state': 'AL', 'city': 'HEADLAND'}, 'pop': 4595}
# {'_id': {'state': 'AL', 'city': 'LESTER'}, 'pop': 3108}
# {'_id': {'state': 'AL', 'city': 'FAYETTE'}, 'pop': 10776}
# {'_id': {'state': 'AL', 'city': 'CAMPBELL'}, 'pop': 392}
# {'_id': {'state': 'AL', 'city': 'CHEROKEE'}, 'pop': 4811}
# {'_id': {'state': 'AL', 'city': 'VALLEY HEAD'}, 'pop': 1211}
# {'_id': {'state': 'AL', 'city': 'SUMITON'}, 'pop': 3066}
# {'_id': {'state': 'AL', 'city': 'LETOHATCHEE'}, 'pop': 2348}
# {'_id': {'state': 'AL', 'city': 'CAMP HILL'}, 'pop': 2422}
# {'_id': {'state': 'AL', 'city': 'LINCOLN'}, 'pop': 5033}
# {'_id': {'state': 'AL', 'city': 'TRENTON'}, 'pop': 381}
# {'_id': {'state': 'AL', 'city': 'OAKMAN'}, 'pop': 3700}
# {'_id': {'state': 'AL', 'city': 'WEOGUFKA'}, 'pop': 1249}
# {'_id': {'state': 'AL', 'city': 'THEODORE'}, 'pop': 20185}
# {'_id': {'state': 'AL', 'city': 'BAILEYTON'}, 'pop': 1781}
# {'_id': {'state': 'AL', 'city': 'MAGNOLIA SPRINGS'}, 'pop': 1088}
# {'_id': {'state': 'AL', 'city': 'SALITPA'}, 'pop': 896}
# {'_id': {'state': 'AL', 'city': 'BON SECOUR'}, 'pop': 2001}
# {'_id': {'state': 'AL', 'city': 'PENNINGTON'}, 'pop': 1459}
# {'_id': {'state': 'AL', 'city': 'FLAT ROCK'}, 'pop': 2141}
# {'_id': {'state': 'AL', 'city': 'CLEVELAND'}, 'pop': 2369}
# {'_id': {'state': 'AL', 'city': 'LEESBURG'}, 'pop': 3189}
# {'_id': {'state': 'AL', 'city': 'RAGLAND'}, 'pop': 2797}
# {'_id': {'state': 'AL', 'city': 'MERIDIANVILLE'}, 'pop': 2597}
# {'_id': {'state': 'AR', 'city': 'CLEVELAND'}, 'pop': 1244}
# {'_id': {'state': 'AR', 'city': 'LONOKE'}, 'pop': 6733}
# {'_id': {'state': 'AR', 'city': 'OIL TROUGH'}, 'pop': 674}
# {'_id': {'state': 'AR', 'city': 'HUNTINGTON'}, 'pop': 2608}
# {'_id': {'state': 'AR', 'city': 'OZARK'}, 'pop': 7338}
# {'_id': {'state': 'AR', 'city': 'WITTS SPRINGS'}, 'pop': 546}
# {'_id': {'state': 'AR', 'city': 'FORREST CITY'}, 'pop': 17751}
# {'_id': {'state': 'AR', 'city': 'FORT CHAFFEE'}, 'pop': 224}
# {'_id': {'state': 'AR', 'city': 'HOXIE'}, 'pop': 3436}
# {'_id': {'state': 'AR', 'city': 'BULL SHOALS'}, 'pop': 1967}
# {'_id': {'state': 'AR', 'city': 'MANSFIELD'}, 'pop': 2607}
# {'_id': {'state': 'AR', 'city': 'WABBASEKA'}, 'pop': 1021}
# {'_id': {'state': 'AR', 'city': 'WIDEMAN'}, 'pop': 89}
# {'_id': {'state': 'AR', 'city': 'BENTON'}, 'pop': 36525}
# {'_id': {'state': 'AR', 'city': 'HANOVER'}, 'pop': 5553}
# {'_id': {'state': 'AR', 'city': 'JOINER'}, 'pop': 986}
# {'_id': {'state': 'AR', 'city': 'CONCORD'}, 'pop': 1168}
# {'_id': {'state': 'AR', 'city': 'STURKIE'}, 'pop': 168}
# {'_id': {'state': 'AR', 'city': 'LANGLEY'}, 'pop': 215}
# {'_id': {'state': 'AR', 'city': 'READER'}, 'pop': 1416}
# {'_id': {'state': 'AR', 'city': 'SPRINGDALE'}, 'pop': 20104}
# {'_id': {'state': 'AR', 'city': 'SEDGWICK'}, 'pop': 503}
# {'_id': {'state': 'AR', 'city': 'CARTHAGE'}, 'pop': 1255}
# {'_id': {'state': 'AR', 'city': 'CHARLESTON'}, 'pop': 3173}
# {'_id': {'state': 'AR', 'city': 'LEAD HILL'}, 'pop': 1818}
# {'_id': {'state': 'AR', 'city': 'RUSSELLVILLE'}, 'pop': 25169}
# {'_id': {'state': 'AR', 'city': 'MC CRORY'}, 'pop': 4029}
# {'_id': {'state': 'AR', 'city': 'TICHNOR'}, 'pop': 331}
# {'_id': {'state': 'AR', 'city': 'JASPER'}, 'pop': 1632}
# {'_id': {'state': 'AR', 'city': 'WILSON'}, 'pop': 1185}
# {'_id': {'state': 'AR', 'city': 'MINTURN'}, 'pop': 364}
# {'_id': {'state': 'AR', 'city': 'GLENCOE'}, 'pop': 514}
# {'_id': {'state': 'AR', 'city': 'LEACHVILLE'}, 'pop': 2810}
# {'_id': {'state': 'AR', 'city': 'NEW BLAINE'}, 'pop': 891}
# {'_id': {'state': 'AR', 'city': 'CHERRY VALLEY'}, 'pop': 1273}
# {'_id': {'state': 'AR', 'city': 'ROSELAND'}, 'pop': 3855}
# {'_id': {'state': 'AR', 'city': 'OMAHA'}, 'pop': 1251}
# {'_id': {'state': 'AR', 'city': 'ROE'}, 'pop': 392}
# {'_id': {'state': 'AR', 'city': 'O KEAN'}, 'pop': 420}
# {'_id': {'state': 'AR', 'city': 'GUION'}, 'pop': 226}
# {'_id': {'state': 'AR', 'city': 'HARRISBURG'}, 'pop': 5961}
# {'_id': {'state': 'AR', 'city': 'MARSHALL'}, 'pop': 2882}
# {'_id': {'state': 'AR', 'city': 'MORRILTON'}, 'pop': 12976}
# {'_id': {'state': 'AR', 'city': 'MARION'}, 'pop': 7891}
# {'_id': {'state': 'AR', 'city': 'FOREMAN'}, 'pop': 2740}
# {'_id': {'state': 'AR', 'city': 'GREENWOOD'}, 'pop': 8385}
# {'_id': {'state': 'AR', 'city': 'WALDRON'}, 'pop': 6884}
# {'_id': {'state': 'AR', 'city': 'HOUSTON'}, 'pop': 642}
# {'_id': {'state': 'AR', 'city': 'ENOLA'}, 'pop': 500}
# {'_id': {'state': 'AR', 'city': 'POTTSVILLE'}, 'pop': 2494}
# {'_id': {'state': 'AR', 'city': 'WESTERN GROVE'}, 'pop': 933}
# {'_id': {'state': 'AR', 'city': 'DELAPLAINE'}, 'pop': 719}
# {'_id': {'state': 'AR', 'city': 'ZION'}, 'pop': 1880}
# {'_id': {'state': 'AR', 'city': 'WILMOT'}, 'pop': 1267}
# {'_id': {'state': 'AR', 'city': 'LONDON'}, 'pop': 2396}
# {'_id': {'state': 'AR', 'city': 'PALESTINE'}, 'pop': 1371}
# {'_id': {'state': 'AR', 'city': 'PAYNEWAY'}, 'pop': 8179}
# {'_id': {'state': 'AR', 'city': 'CADDO GAP'}, 'pop': 2257}
# {'_id': {'state': 'AR', 'city': 'SUCCESS'}, 'pop': 286}
# {'_id': {'state': 'AR', 'city': 'MC DOUGAL'}, 'pop': 1552}
# {'_id': {'state': 'AR', 'city': 'HATTIEVILLE'}, 'pop': 360}
# {'_id': {'state': 'AR', 'city': 'THIDA'}, 'pop': 616}
# {'_id': {'state': 'AR', 'city': 'BRUNO'}, 'pop': 236}
# {'_id': {'state': 'AR', 'city': 'SMITHVILLE'}, 'pop': 427}
# {'_id': {'state': 'AR', 'city': 'CAMP'}, 'pop': 401}
# {'_id': {'state': 'AR', 'city': 'SWIFTON'}, 'pop': 1172}
# {'_id': {'state': 'AR', 'city': 'GOODWIN'}, 'pop': 597}
# {'_id': {'state': 'AR', 'city': 'LEOLA'}, 'pop': 769}
# {'_id': {'state': 'AR', 'city': 'RISON'}, 'pop': 5669}
# {'_id': {'state': 'AR', 'city': 'OGDEN'}, 'pop': 779}
# {'_id': {'state': 'AR', 'city': 'WILTON'}, 'pop': 983}
# {'_id': {'state': 'AR', 'city': 'LOCKESBURG'}, 'pop': 2239}
# {'_id': {'state': 'AR', 'city': 'WATSON'}, 'pop': 1003}
# {'_id': {'state': 'AR', 'city': 'MARMADUKE'}, 'pop': 2082}
# {'_id': {'state': 'AR', 'city': 'KNOBEL'}, 'pop': 518}
# {'_id': {'state': 'AR', 'city': 'CHARLOTTE'}, 'pop': 797}
# {'_id': {'state': 'AR', 'city': 'VALLEY SPRINGS'}, 'pop': 1050}
# {'_id': {'state': 'AR', 'city': 'ATKINS'}, 'pop': 4835}
# {'_id': {'state': 'AR', 'city': 'PERRYVILLE'}, 'pop': 3851}
# {'_id': {'state': 'AR', 'city': 'MC RAE'}, 'pop': 1095}
# {'_id': {'state': 'AR', 'city': 'DRASCO'}, 'pop': 886}
# {'_id': {'state': 'AR', 'city': 'HATFIELD'}, 'pop': 1048}
# {'_id': {'state': 'AR', 'city': 'AGNOS'}, 'pop': 1433}
# {'_id': {'state': 'AR', 'city': 'PROCTOR'}, 'pop': 953}
# {'_id': {'state': 'AR', 'city': 'LAKE CATHERINE'}, 'pop': 27402}
# {'_id': {'state': 'AR', 'city': 'EVENING SHADE'}, 'pop': 1356}
# {'_id': {'state': 'AR', 'city': 'WITTER'}, 'pop': 179}
# {'_id': {'state': 'AR', 'city': 'BLUFF CITY'}, 'pop': 546}
# {'_id': {'state': 'AR', 'city': 'BEE BRANCH'}, 'pop': 1344}
# {'_id': {'state': 'AR', 'city': 'BLACK ROCK'}, 'pop': 1190}
# {'_id': {'state': 'AR', 'city': 'PEARCY'}, 'pop': 3215}
# {'_id': {'state': 'AR', 'city': 'PORTIA'}, 'pop': 646}
# {'_id': {'state': 'AR', 'city': 'PELSOR'}, 'pop': 117}
# {'_id': {'state': 'AR', 'city': 'QUITMAN'}, 'pop': 3043}
# {'_id': {'state': 'AR', 'city': 'CASA'}, 'pop': 649}
# {'_id': {'state': 'AR', 'city': 'OAK GROVE'}, 'pop': 956}
# {'_id': {'state': 'AR', 'city': 'LEXA'}, 'pop': 903}
# {'_id': {'state': 'AR', 'city': 'BRANCH'}, 'pop': 597}
# {'_id': {'state': 'AR', 'city': 'PERRY'}, 'pop': 648}
# {'_id': {'state': 'AR', 'city': 'BUCKNER'}, 'pop': 1364}
# {'_id': {'state': 'AR', 'city': 'DATTO'}, 'pop': 308}
# {'_id': {'state': 'AR', 'city': 'WINTHROP'}, 'pop': 950}
# {'_id': {'state': 'AR', 'city': 'WHEATLEY'}, 'pop': 542}
# {'_id': {'state': 'AR', 'city': 'CRUMROD'}, 'pop': 514}
# {'_id': {'state': 'AR', 'city': 'MARVELL'}, 'pop': 2733}
# {'_id': {'state': 'AR', 'city': 'DESHA'}, 'pop': 876}
# {'_id': {'state': 'AR', 'city': 'EVERTON'}, 'pop': 436}
# {'_id': {'state': 'AR', 'city': 'GRIFFITHVILLE'}, 'pop': 582}
# {'_id': {'state': 'AR', 'city': 'NORTH CEDAR'}, 'pop': 23095}
# {'_id': {'state': 'AR', 'city': 'NEWPORT'}, 'pop': 13502}
# {'_id': {'state': 'AR', 'city': 'OZAN'}, 'pop': 1695}
# {'_id': {'state': 'AR', 'city': 'PRIM'}, 'pop': 74}
# {'_id': {'state': 'AR', 'city': 'RAVENDEN SPRINGS'}, 'pop': 944}
# {'_id': {'state': 'AR', 'city': 'INGALLS'}, 'pop': 2150}
# {'_id': {'state': 'AR', 'city': 'WARD'}, 'pop': 3503}
# {'_id': {'state': 'AR', 'city': 'GLENWOOD'}, 'pop': 2720}
# {'_id': {'state': 'AR', 'city': 'WEST MEMPHIS'}, 'pop': 28720}
# {'_id': {'state': 'AR', 'city': 'MAGNOLIA'}, 'pop': 16379}
# {'_id': {'state': 'AR', 'city': 'GURDON'}, 'pop': 4180}
# {'_id': {'state': 'AR', 'city': 'WILBURN'}, 'pop': 1924}
# {'_id': {'state': 'AR', 'city': 'MOUNT VERNON'}, 'pop': 534}
# {'_id': {'state': 'AR', 'city': 'LESLIE'}, 'pop': 1768}
# {'_id': {'state': 'AR', 'city': 'MAGAZINE'}, 'pop': 1336}
# {'_id': {'state': 'AR', 'city': 'BATES'}, 'pop': 213}
# {'_id': {'state': 'AR', 'city': 'ONIA'}, 'pop': 444}
# {'_id': {'state': 'AR', 'city': 'ALTUS'}, 'pop': 2292}
# {'_id': {'state': 'AR', 'city': 'MOUNT PLEASANT'}, 'pop': 1264}
# {'_id': {'state': 'AR', 'city': 'CONWAY'}, 'pop': 43236}
# {'_id': {'state': 'AR', 'city': 'ELIZABETH'}, 'pop': 390}
# {'_id': {'state': 'AR', 'city': 'HUMPHREY'}, 'pop': 851}
# {'_id': {'state': 'AR', 'city': 'JUNCTION CITY'}, 'pop': 1553}
# {'_id': {'state': 'AR', 'city': 'WRIGHT'}, 'pop': 302}
# {'_id': {'state': 'AR', 'city': 'LAMAR'}, 'pop': 2905}
# ...
# {'_id': {'state': 'WV', 'city': 'CHARMCO'}, 'pop': 1643}
# {'_id': {'state': 'WV', 'city': 'TURTLE CREEK'}, 'pop': 669}
# {'_id': {'state': 'WV', 'city': 'BALD KNOB'}, 'pop': 666}
# {'_id': {'state': 'WV', 'city': 'ELKINS'}, 'pop': 14027}
# {'_id': {'state': 'WV', 'city': 'TALCOTT'}, 'pop': 511}
# {'_id': {'state': 'WV', 'city': 'HINTON'}, 'pop': 6150}
# {'_id': {'state': 'WV', 'city': 'DUHRING'}, 'pop': 5336}
# {'_id': {'state': 'WV', 'city': 'UPPERGLADE'}, 'pop': 383}
# {'_id': {'state': 'WV', 'city': 'PALERMO'}, 'pop': 115}
# {'_id': {'state': 'WV', 'city': 'BLUEWELL'}, 'pop': 22561}
# {'_id': {'state': 'WV', 'city': 'WAYNE'}, 'pop': 4992}
# {'_id': {'state': 'WV', 'city': 'FLOE'}, 'pop': 886}
# {'_id': {'state': 'WV', 'city': 'CHARLES TOWN'}, 'pop': 14351}
# {'_id': {'state': 'WV', 'city': 'ELM GROVE'}, 'pop': 49136}
# {'_id': {'state': 'WV', 'city': 'WILBUR'}, 'pop': 1201}
# {'_id': {'state': 'WV', 'city': 'CLEAR FORK'}, 'pop': 1173}
# {'_id': {'state': 'WV', 'city': 'JACKSONBURG'}, 'pop': 406}
# {'_id': {'state': 'WV', 'city': 'PIPESTEM'}, 'pop': 677}
# {'_id': {'state': 'WV', 'city': 'LEHEW'}, 'pop': 190}
# {'_id': {'state': 'WV', 'city': 'HANOVER'}, 'pop': 1523}
# {'_id': {'state': 'WV', 'city': 'MALDEN'}, 'pop': 7992}
# {'_id': {'state': 'WV', 'city': 'SAINT ALBANS'}, 'pop': 24409}
# {'_id': {'state': 'WV', 'city': 'KIEFFER'}, 'pop': 2}
# {'_id': {'state': 'WV', 'city': 'FLOWER'}, 'pop': 308}
# {'_id': {'state': 'WV', 'city': 'AUGUSTA'}, 'pop': 2769}
# {'_id': {'state': 'WV', 'city': 'CENTURY'}, 'pop': 235}
# {'_id': {'state': 'WV', 'city': 'NORTH SPRING'}, 'pop': 226}
# {'_id': {'state': 'WV', 'city': 'COMFORT'}, 'pop': 889}
# {'_id': {'state': 'WV', 'city': 'MANHEIM'}, 'pop': 404}
# {'_id': {'state': 'WV', 'city': 'ORGAS'}, 'pop': 840}
# {'_id': {'state': 'WV', 'city': 'HUNDRED'}, 'pop': 1214}
# {'_id': {'state': 'WV', 'city': 'BOMONT'}, 'pop': 129}
# {'_id': {'state': 'WV', 'city': 'STATTS MILLS'}, 'pop': 368}
# {'_id': {'state': 'WV', 'city': 'RED HOUSE'}, 'pop': 3472}
# {'_id': {'state': 'WV', 'city': 'BARRETT'}, 'pop': 50}
# {'_id': {'state': 'WV', 'city': 'BOLT'}, 'pop': 524}
# {'_id': {'state': 'WV', 'city': 'HURRICANE'}, 'pop': 16250}
# {'_id': {'state': 'WV', 'city': 'HERNSHAW'}, 'pop': 745}
# {'_id': {'state': 'WV', 'city': 'SHOCK'}, 'pop': 250}
# {'_id': {'state': 'WV', 'city': 'ORLANDO'}, 'pop': 209}
# {'_id': {'state': 'WV', 'city': 'STRANGE CREEK'}, 'pop': 206}
# {'_id': {'state': 'WV', 'city': 'MEADOR'}, 'pop': 1640}
# {'_id': {'state': 'WV', 'city': 'COALTON'}, 'pop': 1422}
# {'_id': {'state': 'WV', 'city': 'JUNCTION'}, 'pop': 200}
# {'_id': {'state': 'WV', 'city': 'BOB WHITE'}, 'pop': 570}
# {'_id': {'state': 'WV', 'city': 'EDMOND'}, 'pop': 69}
# {'_id': {'state': 'WV', 'city': 'SANDYVILLE'}, 'pop': 1611}
# {'_id': {'state': 'WV', 'city': 'GERRARDSTOWN'}, 'pop': 2481}
# {'_id': {'state': 'WV', 'city': 'COOL RIDGE'}, 'pop': 1731}
# {'_id': {'state': 'WV', 'city': 'POE'}, 'pop': 818}
# {'_id': {'state': 'WV', 'city': 'BIG RUN'}, 'pop': 647}
# {'_id': {'state': 'WV', 'city': 'FRAZIERS BOTTOM'}, 'pop': 911}
# {'_id': {'state': 'WV', 'city': 'CALVIN'}, 'pop': 603}
# {'_id': {'state': 'WV', 'city': 'BIG OTTER'}, 'pop': 145}
# {'_id': {'state': 'WV', 'city': 'HENDRICKS'}, 'pop': 318}
# {'_id': {'state': 'WV', 'city': 'STOUTS MILLS'}, 'pop': 717}
# {'_id': {'state': 'WV', 'city': 'GAULEY MILLS'}, 'pop': 1191}
# {'_id': {'state': 'WV', 'city': 'MABEN'}, 'pop': 415}
# {'_id': {'state': 'WV', 'city': 'HAZELGREEN'}, 'pop': 203}
# {'_id': {'state': 'WV', 'city': 'MARIANNA'}, 'pop': 1008}
# {'_id': {'state': 'WV', 'city': 'MONTERVILLE'}, 'pop': 79}
# {'_id': {'state': 'WV', 'city': 'BEESON'}, 'pop': 140}
# {'_id': {'state': 'WV', 'city': 'CLOTHIER'}, 'pop': 1379}
# {'_id': {'state': 'WV', 'city': 'DANIELS'}, 'pop': 2533}
# {'_id': {'state': 'WV', 'city': 'LOBATA'}, 'pop': 3232}
# {'_id': {'state': 'WV', 'city': 'MARMET'}, 'pop': 4317}
# {'_id': {'state': 'WV', 'city': 'MAMMOTH'}, 'pop': 486}
# {'_id': {'state': 'WV', 'city': 'AMIGO'}, 'pop': 684}
# {'_id': {'state': 'WV', 'city': 'JOLO'}, 'pop': 3086}
# {'_id': {'state': 'WV', 'city': 'GLEN ROGERS'}, 'pop': 367}
# {'_id': {'state': 'WV', 'city': 'CORINTH'}, 'pop': 503}
# {'_id': {'state': 'WV', 'city': 'CRESTON'}, 'pop': 340}
# {'_id': {'state': 'WV', 'city': 'WAVERLY'}, 'pop': 2836}
# {'_id': {'state': 'WV', 'city': 'WILSIE'}, 'pop': 150}
# {'_id': {'state': 'WV', 'city': 'GAY'}, 'pop': 1037}
# {'_id': {'state': 'WV', 'city': 'RICHWOOD'}, 'pop': 4129}
# {'_id': {'state': 'WV', 'city': 'CAMERON'}, 'pop': 2743}
# {'_id': {'state': 'WV', 'city': 'NORTH PARKERSBUR'}, 'pop': 9260}
# {'_id': {'state': 'WV', 'city': 'CHAPMANVILLE'}, 'pop': 8874}
# {'_id': {'state': 'WV', 'city': 'BROHARD'}, 'pop': 23}
# {'_id': {'state': 'WV', 'city': 'BUNKER HILL'}, 'pop': 5419}
# {'_id': {'state': 'WV', 'city': 'NAPIER'}, 'pop': 107}
# {'_id': {'state': 'WV', 'city': 'BAISDEN'}, 'pop': 1183}
# {'_id': {'state': 'WV', 'city': 'BOLAIR'}, 'pop': 3914}
# {'_id': {'state': 'WV', 'city': 'WYMER'}, 'pop': 128}
# {'_id': {'state': 'WV', 'city': 'CARBON'}, 'pop': 2581}
# {'_id': {'state': 'WV', 'city': 'MONTGOMERY'}, 'pop': 10392}
# {'_id': {'state': 'WV', 'city': 'DEHUE'}, 'pop': 2524}
# {'_id': {'state': 'WV', 'city': 'EAST LYNN'}, 'pop': 1722}
# {'_id': {'state': 'WV', 'city': 'LOST CITY'}, 'pop': 190}
# {'_id': {'state': 'WV', 'city': 'ALUM CREEK'}, 'pop': 1450}
# {'_id': {'state': 'WV', 'city': 'SPRING DALE'}, 'pop': 79}
# {'_id': {'state': 'WV', 'city': 'WALLBACK'}, 'pop': 181}
# {'_id': {'state': 'WV', 'city': 'CRAWFORD'}, 'pop': 517}
# {'_id': {'state': 'WV', 'city': 'BARNABUS'}, 'pop': 2369}
# {'_id': {'state': 'WV', 'city': 'WOLFCREEK'}, 'pop': 249}
# {'_id': {'state': 'WV', 'city': 'REEDY'}, 'pop': 3014}
# {'_id': {'state': 'WV', 'city': 'SALT ROCK'}, 'pop': 1482}
# {'_id': {'state': 'WV', 'city': 'BIG CHIMNEY'}, 'pop': 20267}
# {'_id': {'state': 'WV', 'city': 'FOSTER'}, 'pop': 1584}
# {'_id': {'state': 'WV', 'city': 'WAITEVILLE'}, 'pop': 62}
# {'_id': {'state': 'WV', 'city': 'BAXTER'}, 'pop': 748}
# {'_id': {'state': 'WV', 'city': 'GHENT'}, 'pop': 749}
# {'_id': {'state': 'WV', 'city': 'BRAMWELL'}, 'pop': 762}
# {'_id': {'state': 'WV', 'city': 'ROMANCE'}, 'pop': 1880}
# {'_id': {'state': 'WV', 'city': 'RIVESVILLE'}, 'pop': 2938}
# {'_id': {'state': 'WV', 'city': 'REEDSVILLE'}, 'pop': 3551}
# {'_id': {'state': 'WV', 'city': 'BROADDUS'}, 'pop': 7934}
# {'_id': {'state': 'WV', 'city': 'WINFIELD'}, 'pop': 3958}
# {'_id': {'state': 'WV', 'city': 'AMBOY'}, 'pop': 1143}
# {'_id': {'state': 'WV', 'city': 'HAMBLETON'}, 'pop': 930}
# {'_id': {'state': 'WV', 'city': 'CLEM'}, 'pop': 1276}
# {'_id': {'state': 'WV', 'city': 'NAOMA'}, 'pop': 864}
# {'_id': {'state': 'WV', 'city': 'LAHMANSVILLE'}, 'pop': 32}
# {'_id': {'state': 'WV', 'city': 'PINEVILLE'}, 'pop': 4142}
# {'_id': {'state': 'WV', 'city': 'EGLON'}, 'pop': 249}
# {'_id': {'state': 'WV', 'city': 'SMITHFIELD'}, 'pop': 775}
# {'_id': {'state': 'WV', 'city': 'DAVISVILLE'}, 'pop': 3667}
# {'_id': {'state': 'WV', 'city': 'SLATYFORK'}, 'pop': 448}
# {'_id': {'state': 'WV', 'city': 'FAIRDALE'}, 'pop': 175}
# {'_id': {'state': 'WV', 'city': 'IAEGER'}, 'pop': 5720}
# {'_id': {'state': 'WV', 'city': 'SUGAR GROVE'}, 'pop': 512}
# {'_id': {'state': 'WV', 'city': 'BURNWELL'}, 'pop': 23}
# {'_id': {'state': 'WV', 'city': 'SOUTH CHARLESTON'}, 'pop': 18377}
# {'_id': {'state': 'WV', 'city': 'DAVIS'}, 'pop': 1459}
# {'_id': {'state': 'WV', 'city': 'SULLIVAN'}, 'pop': 99}
# {'_id': {'state': 'WV', 'city': 'HARRISON'}, 'pop': 163}
# {'_id': {'state': 'WV', 'city': 'ROCKPORT'}, 'pop': 1068}
# {'_id': {'state': 'WV', 'city': 'KIRBY'}, 'pop': 303}
# {'_id': {'state': 'WV', 'city': 'TRIADELPHIA'}, 'pop': 2320}
# {'_id': {'state': 'WV', 'city': 'MAYSVILLE'}, 'pop': 2615}
# {'_id': {'state': 'WV', 'city': 'LOOKOUT'}, 'pop': 338}
# {'_id': {'state': 'WV', 'city': 'ENTERPRISE'}, 'pop': 1800}
# {'_id': {'state': 'WV', 'city': 'LESTER'}, 'pop': 1157}
# {'_id': {'state': 'WV', 'city': 'GANDEEVILLE'}, 'pop': 715}
# {'_id': {'state': 'WV', 'city': 'PADEN CITY'}, 'pop': 3513}
# {'_id': {'state': 'WV', 'city': 'UNION'}, 'pop': 1737}
# {'_id': {'state': 'WV', 'city': 'BUFFALO'}, 'pop': 1898}
# {'_id': {'state': 'WV', 'city': 'MARFRANCE'}, 'pop': 1936}
# {'_id': {'state': 'WV', 'city': 'KIMBERLY'}, 'pop': 108}
# {'_id': {'state': 'WV', 'city': 'CAIRO'}, 'pop': 1379}
# {'_id': {'state': 'WV', 'city': 'DRYFORK'}, 'pop': 116}
# {'_id': {'state': 'WV', 'city': 'SPRINGFIELD'}, 'pop': 1321}
# {'_id': {'state': 'WV', 'city': 'DINGESS'}, 'pop': 2012}
# {'_id': {'state': 'WV', 'city': 'TUNNELTON'}, 'pop': 4076}
# {'_id': {'state': 'WY', 'city': 'BASIN'}, 'pop': 1580}
# {'_id': {'state': 'WY', 'city': 'LAGRANGE'}, 'pop': 413}
# {'_id': {'state': 'WY', 'city': 'HYATTVILLE'}, 'pop': 97}
# {'_id': {'state': 'WY', 'city': 'SHOSHONI'}, 'pop': 600}
# {'_id': {'state': 'WY', 'city': 'MEETEETSE'}, 'pop': 1010}
# {'_id': {'state': 'WY', 'city': 'KEELINE'}, 'pop': 209}
# {'_id': {'state': 'WY', 'city': 'GILLETTE'}, 'pop': 26155}
# {'_id': {'state': 'WY', 'city': 'ROZET'}, 'pop': 900}
# {'_id': {'state': 'WY', 'city': 'RYAN PARK'}, 'pop': 2462}
# {'_id': {'state': 'WY', 'city': 'VAN TASSELL'}, 'pop': 385}
# {'_id': {'state': 'WY', 'city': 'MIDWEST'}, 'pop': 756}
# {'_id': {'state': 'WY', 'city': 'LYMAN'}, 'pop': 2327}
# {'_id': {'state': 'WY', 'city': 'SUNDANCE'}, 'pop': 1827}
# {'_id': {'state': 'WY', 'city': 'MOOSE'}, 'pop': 519}
# {'_id': {'state': 'WY', 'city': 'ETHETE'}, 'pop': 11770}
# {'_id': {'state': 'WY', 'city': 'MC KINNON'}, 'pop': 188}
# {'_id': {'state': 'WY', 'city': 'AUBURN'}, 'pop': 488}
# {'_id': {'state': 'WY', 'city': 'FREEDOM'}, 'pop': 212}
# {'_id': {'state': 'WY', 'city': 'KEMMERER'}, 'pop': 4258}
# {'_id': {'state': 'WY', 'city': 'ROCK RIVER'}, 'pop': 236}
# {'_id': {'state': 'WY', 'city': 'HANNA'}, 'pop': 1585}
# {'_id': {'state': 'WY', 'city': 'CHUGWATER'}, 'pop': 295}
# {'_id': {'state': 'WY', 'city': 'HAWK SPRINGS'}, 'pop': 125}
# {'_id': {'state': 'WY', 'city': 'BURLINGTON'}, 'pop': 435}
# {'_id': {'state': 'WY', 'city': 'ARMINTO'}, 'pop': 14}
# {'_id': {'state': 'WY', 'city': 'JAY EM'}, 'pop': 399}
# {'_id': {'state': 'WY', 'city': 'COKEVILLE'}, 'pop': 905}
# {'_id': {'state': 'WY', 'city': 'KAYCEE'}, 'pop': 876}
# {'_id': {'state': 'WY', 'city': 'GRASS CREEK'}, 'pop': 4809}
# {'_id': {'state': 'WY', 'city': 'POWELL'}, 'pop': 9608}
# {'_id': {'state': 'WY', 'city': 'WAPITI'}, 'pop': 214}
# {'_id': {'state': 'WY', 'city': 'BONDURANT'}, 'pop': 116}
# {'_id': {'state': 'WY', 'city': 'JELM'}, 'pop': 470}
# {'_id': {'state': 'WY', 'city': 'MERIDEN'}, 'pop': 40}
# {'_id': {'state': 'WY', 'city': 'VETERAN'}, 'pop': 148}
# {'_id': {'state': 'WY', 'city': 'WRIGHT'}, 'pop': 2132}
# {'_id': {'state': 'WY', 'city': 'LUSK'}, 'pop': 1724}
# {'_id': {'state': 'WY', 'city': 'FISHING BRIDGE'}, 'pop': 443}
# {'_id': {'state': 'WY', 'city': 'ACME'}, 'pop': 868}
# {'_id': {'state': 'WY', 'city': 'WORLAND'}, 'pop': 7693}
# {'_id': {'state': 'WY', 'city': 'PINEDALE'}, 'pop': 2326}
# {'_id': {'state': 'WY', 'city': 'RANCHESTER'}, 'pop': 32}
# {'_id': {'state': 'WY', 'city': 'LANCE CREEK'}, 'pop': 181}
# {'_id': {'state': 'WY', 'city': 'GARRETT'}, 'pop': 120}
# {'_id': {'state': 'WY', 'city': 'GREYBULL'}, 'pop': 2460}
# {'_id': {'state': 'WY', 'city': 'DANIEL'}, 'pop': 398}
# {'_id': {'state': 'WY', 'city': 'PINE BLUFFS'}, 'pop': 1082}
# {'_id': {'state': 'WY', 'city': 'MARBLETON'}, 'pop': 1861}
# {'_id': {'state': 'WY', 'city': 'BEULAH'}, 'pop': 187}
# {'_id': {'state': 'WY', 'city': 'EVANSVILLE'}, 'pop': 1621}
# {'_id': {'state': 'WY', 'city': 'CROWHEART'}, 'pop': 157}
# {'_id': {'state': 'WY', 'city': 'LA BARGE'}, 'pop': 606}
# {'_id': {'state': 'WY', 'city': 'CASPER'}, 'pop': 58825}
# {'_id': {'state': 'WY', 'city': 'MORAN'}, 'pop': 191}
# {'_id': {'state': 'WY', 'city': 'CARPENTER'}, 'pop': 222}
# {'_id': {'state': 'WY', 'city': 'WHEATLAND'}, 'pop': 5952}
# {'_id': {'state': 'WY', 'city': 'COLTER BAY'}, 'pop': 9078}
# {'_id': {'state': 'WY', 'city': 'FORT BRIDGER'}, 'pop': 3777}
# {'_id': {'state': 'WY', 'city': 'OSAGE'}, 'pop': 292}
# {'_id': {'state': 'WY', 'city': 'ALCOVA'}, 'pop': 10}
# {'_id': {'state': 'WY', 'city': 'HARTVILLE'}, 'pop': 108}
# {'_id': {'state': 'WY', 'city': 'TORRINGTON'}, 'pop': 9575}
# {'_id': {'state': 'WY', 'city': 'SHELL'}, 'pop': 355}
# {'_id': {'state': 'WY', 'city': 'KELLY'}, 'pop': 203}
# {'_id': {'state': 'WY', 'city': 'LOVELL'}, 'pop': 4322}
# {'_id': {'state': 'WY', 'city': 'SINCLAIR'}, 'pop': 530}
# {'_id': {'state': 'WY', 'city': 'STORY'}, 'pop': 63}
# {'_id': {'state': 'WY', 'city': 'SHERIDAN'}, 'pop': 20025}
# {'_id': {'state': 'WY', 'city': 'PARKMAN'}, 'pop': 148}
# {'_id': {'state': 'WY', 'city': 'MEDICINE BOW'}, 'pop': 409}
# {'_id': {'state': 'WY', 'city': 'LOST SPRINGS'}, 'pop': 6}
# {'_id': {'state': 'WY', 'city': 'DIXON'}, 'pop': 253}
# {'_id': {'state': 'WY', 'city': 'BAIROIL'}, 'pop': 236}
# {'_id': {'state': 'WY', 'city': 'DUBOIS'}, 'pop': 1493}
# {'_id': {'state': 'WY', 'city': 'PINE HAVEN'}, 'pop': 1820}
# {'_id': {'state': 'WY', 'city': 'GROVER'}, 'pop': 335}
# {'_id': {'state': 'WY', 'city': 'OSHOTO'}, 'pop': 57}
# {'_id': {'state': 'WY', 'city': 'ARVADA'}, 'pop': 107}
# {'_id': {'state': 'WY', 'city': 'ETNA'}, 'pop': 524}
# {'_id': {'state': 'WY', 'city': 'LINGLE'}, 'pop': 714}
# {'_id': {'state': 'WY', 'city': 'FORT WASHAKIE'}, 'pop': 1131}
# {'_id': {'state': 'WY', 'city': 'CENTENNIAL'}, 'pop': 446}
# {'_id': {'state': 'WY', 'city': 'RECLUSE'}, 'pop': 183}
# {'_id': {'state': 'WY', 'city': 'CLEARMONT'}, 'pop': 350}
# {'_id': {'state': 'WY', 'city': 'BEDFORD'}, 'pop': 1177}
# {'_id': {'state': 'WY', 'city': 'DEVILS TOWER'}, 'pop': 119}
# {'_id': {'state': 'WY', 'city': 'BUFORD'}, 'pop': 97}
# {'_id': {'state': 'WY', 'city': 'AFTON'}, 'pop': 3201}
# {'_id': {'state': 'WY', 'city': 'SMOOT'}, 'pop': 414}
# {'_id': {'state': 'WY', 'city': 'KINNEAR'}, 'pop': 420}
# {'_id': {'state': 'WY', 'city': 'ENCAMPMENT'}, 'pop': 946}
# {'_id': {'state': 'WY', 'city': 'LARAMIE'}, 'pop': 29349}
# {'_id': {'state': 'WY', 'city': 'BUFFALO'}, 'pop': 5269}
# {'_id': {'state': 'WY', 'city': 'RAWLINS'}, 'pop': 9914}
# {'_id': {'state': 'WY', 'city': 'GREEN RIVER'}, 'pop': 13956}
# {'_id': {'state': 'WY', 'city': 'LONETREE'}, 'pop': 24}
# {'_id': {'state': 'WY', 'city': 'ALADDIN'}, 'pop': 230}
# {'_id': {'state': 'WY', 'city': 'LYSITE'}, 'pop': 81}
# {'_id': {'state': 'WY', 'city': 'ARAPAHOE'}, 'pop': 605}
# {'_id': {'state': 'WY', 'city': 'GLENROCK'}, 'pop': 3483}
# {'_id': {'state': 'WY', 'city': 'GUERNSEY'}, 'pop': 1319}
# {'_id': {'state': 'WY', 'city': 'NEWCASTLE'}, 'pop': 4833}
# {'_id': {'state': 'WY', 'city': 'CODY'}, 'pop': 11985}
# {'_id': {'state': 'WY', 'city': 'DAYTON'}, 'pop': 986}
# {'_id': {'state': 'WY', 'city': 'WAMSUTTER'}, 'pop': 516}
# {'_id': {'state': 'WY', 'city': 'YODER'}, 'pop': 674}
# {'_id': {'state': 'WY', 'city': 'JEFFREY CITY'}, 'pop': 253}
# {'_id': {'state': 'WY', 'city': 'SHAWNEE'}, 'pop': 137}
# {'_id': {'state': 'WY', 'city': 'BOULDER'}, 'pop': 112}
# {'_id': {'state': 'WY', 'city': 'GLENDO'}, 'pop': 471}
# {'_id': {'state': 'WY', 'city': 'SAVERY'}, 'pop': 97}
# {'_id': {'state': 'WY', 'city': 'GAS HILLS'}, 'pop': 15471}
# {'_id': {'state': 'WY', 'city': 'WILSON'}, 'pop': 1099}
# {'_id': {'state': 'WY', 'city': 'FORT LARAMIE'}, 'pop': 325}
# {'_id': {'state': 'WY', 'city': 'UPTON'}, 'pop': 1355}
# {'_id': {'state': 'WY', 'city': 'TIE SIDING'}, 'pop': 19}
# {'_id': {'state': 'WY', 'city': 'EVANSTON'}, 'pop': 12577}
# {'_id': {'state': 'WY', 'city': 'HULETT'}, 'pop': 1054}
# {'_id': {'state': 'WY', 'city': 'BURNS'}, 'pop': 1303}
# {'_id': {'state': 'WY', 'city': 'OTTO'}, 'pop': 120}
# {'_id': {'state': 'WY', 'city': 'PAVILLION'}, 'pop': 1681}
# {'_id': {'state': 'WY', 'city': 'ALBIN'}, 'pop': 310}
# {'_id': {'state': 'WY', 'city': 'DOUGLAS'}, 'pop': 7502}
# {'_id': {'state': 'WY', 'city': 'CHEYENNE'}, 'pop': 70185}
# {'_id': {'state': 'WY', 'city': 'BANNER'}, 'pop': 983}
# {'_id': {'state': 'WY', 'city': 'ROCK SPRINGS'}, 'pop': 23927}
# {'_id': {'state': 'WY', 'city': 'BAGGS'}, 'pop': 384}
# {'_id': {'state': 'WY', 'city': 'FOUR CORNERS'}, 'pop': 38}
# {'_id': {'state': 'WY', 'city': 'CORA'}, 'pop': 30}
# {'_id': {'state': 'WY', 'city': 'TEN SLEEP'}, 'pop': 695}
# {'_id': {'state': 'WY', 'city': 'THAYNE'}, 'pop': 505}
# {'_id': {'state': 'WY', 'city': 'DEAVER'}, 'pop': 499}
# {'_id': {'state': 'WY', 'city': 'MANDERSON'}, 'pop': 657}
# {'_id': {'state': 'WY', 'city': 'MC FADDEN'}, 'pop': 79}

# %%
cursor = db.zipcodes.aggregate( [
   { "$group": { "_id": { "state": "$state", "city": "$city" }, "pop": { "$sum": "$pop" } } },
   { "$group": { "_id": "$_id.state", "avgCityPop": { "$avg": "$pop" } } }
] )

print_cursor(cursor)
# Out:
# {'_id': 'NE', 'avgCityPop': 3034.882692307692}
# {'_id': 'MI', 'avgCityPop': 12087.512353706112}
# {'_id': 'CO', 'avgCityPop': 9981.075757575758}
# {'_id': 'SC', 'avgCityPop': 11139.626198083068}
# {'_id': 'TN', 'avgCityPop': 9656.350495049504}
# {'_id': 'IL', 'avgCityPop': 9954.334494773519}
# {'_id': 'OH', 'avgCityPop': 12700.839578454332}
# {'_id': 'ID', 'avgCityPop': 4320.811158798283}
# {'_id': 'DE', 'avgCityPop': 14481.91304347826}
# {'_id': 'KY', 'avgCityPop': 4767.164721141375}
# {'_id': 'DC', 'avgCityPop': 303450.0}
# {'_id': 'IA', 'avgCityPop': 3123.0821147356583}
# {'_id': 'OK', 'avgCityPop': 6155.743639921722}
# {'_id': 'GA', 'avgCityPop': 11547.62210338681}
# {'_id': 'AL', 'avgCityPop': 7907.2152641878665}
# {'_id': 'SD', 'avgCityPop': 1839.6746031746031}
# {'_id': 'VT', 'avgCityPop': 2315.8765432098767}
# {'_id': 'WA', 'avgCityPop': 12258.670025188916}
# {'_id': 'MS', 'avgCityPop': 7524.023391812865}
# {'_id': 'MT', 'avgCityPop': 2593.987012987013}
# {'_id': 'UT', 'avgCityPop': 9518.508287292818}
# {'_id': 'HI', 'avgCityPop': 15831.842857142858}
# {'_id': 'WI', 'avgCityPop': 7323.00748502994}
# {'_id': 'NJ', 'avgCityPop': 15775.89387755102}
# {'_id': 'NH', 'avgCityPop': 5232.320754716981}
# {'_id': 'MN', 'avgCityPop': 5372.21375921376}
# {'_id': 'CA', 'avgCityPop': 27756.42723880597}
# {'_id': 'FL', 'avgCityPop': 27400.958963282937}
# {'_id': 'IN', 'avgCityPop': 9271.130434782608}
# {'_id': 'KS', 'avgCityPop': 3819.884259259259}
# {'_id': 'AK', 'avgCityPop': 2976.4918032786886}
# {'_id': 'NC', 'avgCityPop': 10622.815705128205}
# {'_id': 'AZ', 'avgCityPop': 20591.16853932584}
# {'_id': 'AR', 'avgCityPop': 4175.355239786856}
# {'_id': 'WY', 'avgCityPop': 3384.5373134328356}
# {'_id': 'PA', 'avgCityPop': 8679.067202337472}
# {'_id': 'MO', 'avgCityPop': 5672.195338512764}
# {'_id': 'ND', 'avgCityPop': 1645.0309278350514}
# {'_id': 'ME', 'avgCityPop': 3006.4901960784314}
# {'_id': 'NV', 'avgCityPop': 18209.590909090908}
# {'_id': 'VA', 'avgCityPop': 8526.177931034483}
# {'_id': 'LA', 'avgCityPop': 10465.496277915632}
# {'_id': 'NM', 'avgCityPop': 5872.360465116279}
# {'_id': 'OR', 'avgCityPop': 8262.561046511628}
# {'_id': 'MD', 'avgCityPop': 12615.775725593667}
# {'_id': 'RI', 'avgCityPop': 19292.653846153848}
# {'_id': 'NY', 'avgCityPop': 13131.680291970803}
# {'_id': 'MA', 'avgCityPop': 14855.37037037037}
# {'_id': 'CT', 'avgCityPop': 14674.625}
# {'_id': 'WV', 'avgCityPop': 2771.4775888717154}
# {'_id': 'TX', 'avgCityPop': 13775.02108678021}

# %% [markdown]
# ### Return Largest and Smallest Cities by State

# %%
cursor = db.zipcodes.aggregate( [
   { "$group":
      {
        "_id": { "state": "$state", "city": "$city" },
        "pop": { "$sum": "$pop" }
      }
   },
   { "$sort": { "pop": 1 } },
   { "$group":
      {
        "_id" : "$_id.state",
        "biggestCity":  { "$last": "$_id.city" },
        "biggestPop":   { "$last": "$pop" },
        "smallestCity": { "$first": "$_id.city" },
        "smallestPop":  { "$first": "$pop" }
      }
   },
  { "$project":
    { "_id": 0,
      "state": "$_id",
      "biggestCity":  { "name": "$biggestCity",  "pop": "$biggestPop" },
      "smallestCity": { "name": "$smallestCity", "pop": "$smallestPop" }
    }
  }
] )

print_cursor(cursor)
# Out:
# {'biggestCity': {'name': 'PHOENIX', 'pop': 890853}, 'smallestCity': {'name': 'HUALAPAI', 'pop': 2}, 'state': 'AZ'}
# {'biggestCity': {'name': 'SEATTLE', 'pop': 520096}, 'smallestCity': {'name': 'BENGE', 'pop': 2}, 'state': 'WA'}
# {'biggestCity': {'name': 'SIOUX FALLS', 'pop': 102046}, 'smallestCity': {'name': 'ZEONA', 'pop': 8}, 'state': 'SD'}
# {'biggestCity': {'name': 'JACKSON', 'pop': 204788}, 'smallestCity': {'name': 'CHUNKY', 'pop': 79}, 'state': 'MS'}
# {'biggestCity': {'name': 'HONOLULU', 'pop': 396643}, 'smallestCity': {'name': 'NINOLE', 'pop': 0}, 'state': 'HI'}
# {'biggestCity': {'name': 'TULSA', 'pop': 389072}, 'smallestCity': {'name': 'SOUTHARD', 'pop': 8}, 'state': 'OK'}
# {'biggestCity': {'name': 'INDIANAPOLIS', 'pop': 348868}, 'smallestCity': {'name': 'WESTPOINT', 'pop': 145}, 'state': 'IN'}
# {'biggestCity': {'name': 'BURLINGTON', 'pop': 39127}, 'smallestCity': {'name': 'UNIV OF VERMONT', 'pop': 0}, 'state': 'VT'}
# {'biggestCity': {'name': 'BIRMINGHAM', 'pop': 242606}, 'smallestCity': {'name': 'ALLEN', 'pop': 0}, 'state': 'AL'}
# {'biggestCity': {'name': 'MILWAUKEE', 'pop': 597324}, 'smallestCity': {'name': 'CLAM LAKE', 'pop': 2}, 'state': 'WI'}
# {'biggestCity': {'name': 'ATLANTA', 'pop': 609591}, 'smallestCity': {'name': 'FORT STEWART', 'pop': 0}, 'state': 'GA'}
# {'biggestCity': {'name': 'BILLINGS', 'pop': 78805}, 'smallestCity': {'name': 'HOMESTEAD', 'pop': 7}, 'state': 'MT'}
# {'biggestCity': {'name': 'SALT LAKE CITY', 'pop': 186346}, 'smallestCity': {'name': 'MODENA', 'pop': 9}, 'state': 'UT'}
# {'biggestCity': {'name': 'COLUMBIA', 'pop': 269521}, 'smallestCity': {'name': 'QUINBY', 'pop': 0}, 'state': 'SC'}
# {'biggestCity': {'name': 'BOISE', 'pop': 165522}, 'smallestCity': {'name': 'KEUTERVILLE', 'pop': 0}, 'state': 'ID'}
# {'biggestCity': {'name': 'MEMPHIS', 'pop': 632837}, 'smallestCity': {'name': 'ALLRED', 'pop': 2}, 'state': 'TN'}
# {'biggestCity': {'name': 'WASHINGTON', 'pop': 606879}, 'smallestCity': {'name': 'PENTAGON', 'pop': 21}, 'state': 'DC'}
# {'biggestCity': {'name': 'DETROIT', 'pop': 963243}, 'smallestCity': {'name': 'LELAND', 'pop': 0}, 'state': 'MI'}
# {'biggestCity': {'name': 'CLEVELAND', 'pop': 536759}, 'smallestCity': {'name': 'ISLE SAINT GEORG', 'pop': 38}, 'state': 'OH'}
# {'biggestCity': {'name': 'CHICAGO', 'pop': 2452177}, 'smallestCity': {'name': 'ANCONA', 'pop': 38}, 'state': 'IL'}
# {'biggestCity': {'name': 'NEWARK', 'pop': 111674}, 'smallestCity': {'name': 'BETHEL', 'pop': 108}, 'state': 'DE'}
# {'biggestCity': {'name': 'DES MOINES', 'pop': 148155}, 'smallestCity': {'name': 'DOUDS', 'pop': 15}, 'state': 'IA'}
# {'biggestCity': {'name': 'LOUISVILLE', 'pop': 288058}, 'smallestCity': {'name': 'BIG LAUREL', 'pop': 0}, 'state': 'KY'}
# {'biggestCity': {'name': 'NEW ORLEANS', 'pop': 496937}, 'smallestCity': {'name': 'LAFITTE', 'pop': 0}, 'state': 'LA'}
# {'biggestCity': {'name': 'PORTLAND', 'pop': 518543}, 'smallestCity': {'name': 'KENT', 'pop': 0}, 'state': 'OR'}
# {'biggestCity': {'name': 'DENVER', 'pop': 451182}, 'smallestCity': {'name': 'CHEYENNE MTN AFB', 'pop': 0}, 'state': 'CO'}
# {'biggestCity': {'name': 'ALBUQUERQUE', 'pop': 449584}, 'smallestCity': {'name': 'MONUMENT', 'pop': 0}, 'state': 'NM'}
# {'biggestCity': {'name': 'VIRGINIA BEACH', 'pop': 385080}, 'smallestCity': {'name': 'WALLOPS ISLAND', 'pop': 0}, 'state': 'VA'}
# {'biggestCity': {'name': 'BALTIMORE', 'pop': 733081}, 'smallestCity': {'name': 'ANNAPOLIS JUNCTI', 'pop': 32}, 'state': 'MD'}
# {'biggestCity': {'name': 'CRANSTON', 'pop': 176404}, 'smallestCity': {'name': 'CLAYVILLE', 'pop': 45}, 'state': 'RI'}
# {'biggestCity': {'name': 'HUNTINGTON', 'pop': 75343}, 'smallestCity': {'name': 'MOUNT CARBON', 'pop': 0}, 'state': 'WV'}
# {'biggestCity': {'name': 'HOUSTON', 'pop': 2095918}, 'smallestCity': {'name': 'ECLETO', 'pop': 0}, 'state': 'TX'}
# {'biggestCity': {'name': 'OMAHA', 'pop': 358930}, 'smallestCity': {'name': 'LAKESIDE', 'pop': 5}, 'state': 'NE'}
# {'biggestCity': {'name': 'BRIDGEPORT', 'pop': 141638}, 'smallestCity': {'name': 'EAST KILLINGLY', 'pop': 25}, 'state': 'CT'}
# {'biggestCity': {'name': 'WORCESTER', 'pop': 169856}, 'smallestCity': {'name': 'BUCKLAND', 'pop': 16}, 'state': 'MA'}
# {'biggestCity': {'name': 'BROOKLYN', 'pop': 2300504}, 'smallestCity': {'name': 'CHILDWOLD', 'pop': 0}, 'state': 'NY'}
# {'biggestCity': {'name': 'MIAMI', 'pop': 825232}, 'smallestCity': {'name': 'CECIL FIELD NAS', 'pop': 0}, 'state': 'FL'}
# {'biggestCity': {'name': 'PORTLAND', 'pop': 63268}, 'smallestCity': {'name': 'BUSTINS ISLAND', 'pop': 0}, 'state': 'ME'}
# {'biggestCity': {'name': 'WICHITA', 'pop': 295115}, 'smallestCity': {'name': 'ARNOLD', 'pop': 0}, 'state': 'KS'}
# {'biggestCity': {'name': 'LOS ANGELES', 'pop': 2102295}, 'smallestCity': {'name': 'VINTON', 'pop': 0}, 'state': 'CA'}
# {'biggestCity': {'name': 'ANCHORAGE', 'pop': 183987}, 'smallestCity': {'name': 'RUSSIAN MISSION', 'pop': 0}, 'state': 'AK'}
# {'biggestCity': {'name': 'NEWARK', 'pop': 275572}, 'smallestCity': {'name': 'IMLAYSTOWN', 'pop': 17}, 'state': 'NJ'}
# {'biggestCity': {'name': 'MINNEAPOLIS', 'pop': 344719}, 'smallestCity': {'name': 'JOHNSON', 'pop': 12}, 'state': 'MN'}
# {'biggestCity': {'name': 'MANCHESTER', 'pop': 106452}, 'smallestCity': {'name': 'WEST NOTTINGHAM', 'pop': 27}, 'state': 'NH'}
# {'biggestCity': {'name': 'PHILADELPHIA', 'pop': 1610956}, 'smallestCity': {'name': 'HAMILTON', 'pop': 0}, 'state': 'PA'}
# {'biggestCity': {'name': 'CHEYENNE', 'pop': 70185}, 'smallestCity': {'name': 'LOST SPRINGS', 'pop': 6}, 'state': 'WY'}
# {'biggestCity': {'name': 'LAS VEGAS', 'pop': 597557}, 'smallestCity': {'name': 'TUSCARORA', 'pop': 1}, 'state': 'NV'}
# {'biggestCity': {'name': 'GRAND FORKS', 'pop': 59527}, 'smallestCity': {'name': 'TROTTERS', 'pop': 12}, 'state': 'ND'}
# {'biggestCity': {'name': 'CHARLOTTE', 'pop': 465833}, 'smallestCity': {'name': 'GLOUCESTER', 'pop': 0}, 'state': 'NC'}
# {'biggestCity': {'name': 'SAINT LOUIS', 'pop': 397802}, 'smallestCity': {'name': 'BENDAVIS', 'pop': 44}, 'state': 'MO'}
# {'biggestCity': {'name': 'LITTLE ROCK', 'pop': 192895}, 'smallestCity': {'name': 'TOMATO', 'pop': 0}, 'state': 'AR'}
